# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
Micro_Retailer=pd.read_csv("Datos_limpios_mexico.csv")
#Lectura de csv

# %%
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26582 entries, 0 to 26581
# Data columns (total 52 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0.1                                  26582 non-null  int64
#  1   listing_url                                   26582 non-null  object
#  2   host_name                                     26582 non-null  object
#  3   host_since                                    26582 non-null  object
#  4   host_location                                 26582 non-null  object
#  5   host_response_time                            26582 non-null  object
#  6   host_is_superhost                             26582 non-null  object
#  7   host_verifications                            26582 non-null  object
#  8   host_has_profile_pic                          26582 non-null  object
# ...

# %%
freq_tbl(Micro_Retailer)
# Out:
#                                             listing_url  frequency  \
# 0      https://www.airbnb.com/rooms/1252229157495978163          1
# 1                    https://www.airbnb.com/rooms/35797          1
# 2                    https://www.airbnb.com/rooms/44616          1
# 3                    https://www.airbnb.com/rooms/67703          1
# 4                    https://www.airbnb.com/rooms/70644          1
# ...                                                 ...        ...
# 26577              https://www.airbnb.com/rooms/1013504          1
# 26578              https://www.airbnb.com/rooms/1011428          1
# 26579              https://www.airbnb.com/rooms/1001517          1
# 26580               https://www.airbnb.com/rooms/171109          1
# 26581               https://www.airbnb.com/rooms/165772          1
#
#        percentage  cumulative_perc
# 0        0.000038         0.000038
# 1        0.000038         0.000075
# 2        0.000038         0.000113
# ...

# %% [markdown]
# 1 Análisis univariado de una variable categorica: 'host_response_time'

# %%
table1=freq_tbl(Micro_Retailer['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour      18792    0.706945         0.706945
# 1         Desconocido       3622    0.136258         0.843202
# 2  within a few hours       1957    0.073621         0.916823
# 3  a few days or more       1108    0.041682         0.958506
# 4        within a day       1103    0.041494         1.000000

# %%
table1_1= table1.drop(['percentage', 'cumulative_perc'], axis=1)
table1_1
# Out:
#    host_response_time  frequency
# 0      within an hour      18792
# 1         Desconocido       3622
# 2  within a few hours       1957
# 3  a few days or more       1108
# 4        within a day       1103

# %%
Filtro1=table1_1[table1_1['frequency']>1]
Filtro1
# Out:
#    host_response_time  frequency
# 0      within an hour      18792
# 1         Desconocido       3622
# 2  within a few hours       1957
# 3  a few days or more       1108
# 4        within a day       1103

# %%
Filtro_index1= Filtro1.set_index('host_response_time')
Filtro_index1
# Out:
#                     frequency
# host_response_time
# within an hour          18792
# Desconocido              3622
# within a few hours       1957
# a few days or more       1108
# within a day             1103

# %%
Filtro_index1.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Tiempo de respuesta')
plt.xlabel('Respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 2 Análisis univariado de una variable categorica: 'host_name'

# %%
table2=freq_tbl(Micro_Retailer['host_name'])
table2
# Out:
#          host_name  frequency  percentage  cumulative_perc
# 0        Alejandra        341    0.012828         0.012828
# 1        Alejandro        293    0.011022         0.023851
# 2             Luis        292    0.010985         0.034836
# 3          Virtual        287    0.010797         0.045632
# 4       Blueground        258    0.009706         0.055338
# ...            ...        ...         ...              ...
# 4087         Eliud          1    0.000038         0.999850
# 4088        Venado          1    0.000038         0.999887
# 4089   Luis Hector          1    0.000038         0.999925
# 4090    Lina Maria          1    0.000038         0.999962
# 4091  Blanca Julia          1    0.000038         1.000000
#
# [4092 rows x 4 columns]

# %%
table2_2= table2.drop(['percentage', 'cumulative_perc'], axis=1)
table2_2
# Out:
#          host_name  frequency
# 0        Alejandra        341
# 1        Alejandro        293
# 2             Luis        292
# 3          Virtual        287
# 4       Blueground        258
# ...            ...        ...
# 4087         Eliud          1
# 4088        Venado          1
# 4089   Luis Hector          1
# 4090    Lina Maria          1
# 4091  Blanca Julia          1
#
# [4092 rows x 2 columns]

# %%
Filtro2=table2_2[table2_2['frequency']>159]
Filtro2
# Out:
#      host_name  frequency
# 0    Alejandra        341
# 1    Alejandro        293
# 2         Luis        292
# 3      Virtual        287
# 4   Blueground        258
# 5        Mr. W        243
# 6         Juan        239
# 7        Jorge        223
# 8       Carlos        222
# 9      Rodrigo        200
# 10     Eduardo        186
# 11        Clau        182
# 12      Daniel        175
# 13     Ricardo        172
# 14      Andrea        160
# 15   Francisco        160

# %%
Filtro_index2= Filtro2.set_index('host_name')
Filtro_index2
# Out:
#             frequency
# host_name
# Alejandra         341
# Alejandro         293
# Luis              292
# Virtual           287
# Blueground        258
# Mr. W             243
# Juan              239
# Jorge             223
# Carlos            222
# Rodrigo           200
# Eduardo           186
# Clau              182
# Daniel            175
# Ricardo           172
# Andrea            160
# Francisco         160

# %%
Filtro_index2.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Nombre del host')
plt.xlabel('Host')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 3 Análisis univariado de una variable categorica: 'host_since'

# %%
table3=freq_tbl(Micro_Retailer['host_since'])
table3
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     30/01/2023        267    0.010044         0.010044
# 1     22/12/2013        216    0.008126         0.018170
# 2     02/02/2020        177    0.006659         0.024829
# 3     28/09/2023        174    0.006546         0.031375
# 4     27/04/2016        156    0.005869         0.037243
# ...          ...        ...         ...              ...
# 4045  22/03/2024          1    0.000038         0.999850
# 4046  07/09/2024          1    0.000038         0.999887
# 4047  21/02/2012          1    0.000038         0.999925
# 4048  02/09/2024          1    0.000038         0.999962
# 4049  07/05/2024          1    0.000038         1.000000
#
# [4050 rows x 4 columns]

# %%
table3_3= table3.drop(['percentage', 'cumulative_perc'], axis=1)
table3_3
# Out:
#       host_since  frequency
# 0     30/01/2023        267
# 1     22/12/2013        216
# 2     02/02/2020        177
# 3     28/09/2023        174
# 4     27/04/2016        156
# ...          ...        ...
# 4045  22/03/2024          1
# 4046  07/09/2024          1
# 4047  21/02/2012          1
# 4048  02/09/2024          1
# 4049  07/05/2024          1
#
# [4050 rows x 2 columns]

# %%
Filtro3=table3_3[table3_3['frequency']>90]
Filtro3
# Out:
#     host_since  frequency
# 0   30/01/2023        267
# 1   22/12/2013        216
# 2   02/02/2020        177
# 3   28/09/2023        174
# 4   27/04/2016        156
# 5   04/08/2018        129
# 6   26/01/2023        127
# 7   26/02/2019        116
# 8   22/08/2016        115
# 9   07/11/2014        107
# 10  15/10/2019        101
# 11  01/12/2015         92

# %%
Filtro_index3= Filtro3.set_index('host_since')
Filtro_index3
# Out:
#             frequency
# host_since
# 30/01/2023        267
# 22/12/2013        216
# 02/02/2020        177
# 28/09/2023        174
# 27/04/2016        156
# 04/08/2018        129
# 26/01/2023        127
# 26/02/2019        116
# 22/08/2016        115
# 07/11/2014        107
# 15/10/2019        101
# 01/12/2015         92

# %%
Filtro_index3.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "orange")
plt.title('Fecha inicio de anfitrión')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 4 Análisis univariado de una variable categorica: 'host_location'

# %%
table4=freq_tbl(Micro_Retailer['host_location'])
table4
# Out:
#                  host_location  frequency  percentage  cumulative_perc
# 0          Mexico City, Mexico      17198    0.646979         0.646979
# 1                  Desconocido       5441    0.204687         0.851667
# 2                       Mexico        949    0.035701         0.887367
# 3    Ciudad de Mï¿½ï¿½xico, Me        383    0.014408         0.901776
# 4     Federal District, Mexico        213    0.008013         0.909789
# ..                         ...        ...         ...              ...
# 396             Hazel Park, MI          1    0.000038         0.999850
# 397        Ojo de Agua, Mexico          1    0.000038         0.999887
# 398         Windermere, Canada          1    0.000038         0.999925
# 399               Palma, Spain          1    0.000038         0.999962
# 400        Copenhagen, Denmark          1    0.000038         1.000000
#
# [401 rows x 4 columns]

# %%
table4_4= table4.drop(['percentage', 'cumulative_perc'], axis=1)
table4_4
# Out:
#                  host_location  frequency
# 0          Mexico City, Mexico      17198
# 1                  Desconocido       5441
# 2                       Mexico        949
# 3    Ciudad de Mï¿½ï¿½xico, Me        383
# 4     Federal District, Mexico        213
# ..                         ...        ...
# 396             Hazel Park, MI          1
# 397        Ojo de Agua, Mexico          1
# 398         Windermere, Canada          1
# 399               Palma, Spain          1
# 400        Copenhagen, Denmark          1
#
# [401 rows x 2 columns]

# %%
Filtro4=table4_4[table4_4['frequency']>62]
Filtro4
# Out:
#                     host_location  frequency
# 0             Mexico City, Mexico      17198
# 1                     Desconocido       5441
# 2                          Mexico        949
# 3       Ciudad de Mï¿½ï¿½xico, Me        383
# 4        Federal District, Mexico        213
# 5                    New York, NY        203
# 6        Ciudad de Mexico, Mexico        200
# 7  Santiago de Querï¿½ï¿½taro, Me        172
# 8    Naucalpan de Juï¿½ï¿½rez, Me         89
# 9              Cuernavaca, Mexico         73

# %%
Filtro_index4= Filtro4.set_index('host_location')
Filtro_index4
# Out:
#                                 frequency
# host_location
# Mexico City, Mexico                 17198
# Desconocido                          5441
# Mexico                                949
# Ciudad de Mï¿½ï¿½xico, Me             383
# Federal District, Mexico              213
# New York, NY                          203
# Ciudad de Mexico, Mexico              200
# Santiago de Querï¿½ï¿½taro, Me        172
# Naucalpan de Juï¿½ï¿½rez, Me           89
# Cuernavaca, Mexico                     73

# %%
Filtro_index4.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Ubicación de anfitrión')
plt.xlabel('Ubicación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 5 Análisis univariado de una variable categorica: 'host_is_superhost'

# %%
table5=freq_tbl(Micro_Retailer['host_is_superhost'])
table5
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f      16855    0.634076         0.634076
# 1                 t       9727    0.365924         1.000000

# %%
table5_5= table5.drop(['percentage', 'cumulative_perc'], axis=1)
table5_5
# Out:
#   host_is_superhost  frequency
# 0                 f      16855
# 1                 t       9727

# %%
Filtro5=table5_5[table5_5['frequency']>1]
Filtro5
# Out:
#   host_is_superhost  frequency
# 0                 f      16855
# 1                 t       9727

# %%
Filtro_index5= Filtro5.set_index('host_is_superhost')
Filtro_index5
# Out:
#                    frequency
# host_is_superhost
# f                      16855
# t                       9727

# %%
Filtro_index5["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 6 Análisis univariado de una variable categorica: 'host_verifications'

# %%
table6=freq_tbl(Micro_Retailer['host_verifications'])
table6
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']      20504    0.771349         0.771349
# 1  ['email', 'phone', 'work_email']       3381    0.127191         0.898540
# 2                         ['phone']       2527    0.095064         0.993605
# 3           ['phone', 'work_email']        105    0.003950         0.997555
# 4                         ['email']         33    0.001241         0.998796
# 5                                []         30    0.001129         0.999925
# 6           ['email', 'work_email']          1    0.000038         0.999962
# 7                    ['work_email']          1    0.000038         1.000000

# %%
table6_6= table6.drop(['percentage', 'cumulative_perc'], axis=1)
table6_6
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']      20504
# 1  ['email', 'phone', 'work_email']       3381
# 2                         ['phone']       2527
# 3           ['phone', 'work_email']        105
# 4                         ['email']         33
# 5                                []         30
# 6           ['email', 'work_email']          1
# 7                    ['work_email']          1

# %%
Filtro6=table6_6[table6_6['frequency']>3]
Filtro6
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']      20504
# 1  ['email', 'phone', 'work_email']       3381
# 2                         ['phone']       2527
# 3           ['phone', 'work_email']        105
# 4                         ['email']         33
# 5                                []         30

# %%
Filtro_index6= Filtro6.set_index('host_verifications')
Filtro_index6
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                    20504
# ['email', 'phone', 'work_email']       3381
# ['phone']                              2527
# ['phone', 'work_email']                 105
# ['email']                                33
# []                                       30

# %%
Filtro_index6["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 7 Análisis univariado de una variable categorica: 'host_has_profile_pic'

# %%
table7=freq_tbl(Micro_Retailer['host_has_profile_pic'])
table7
# Out:
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t      26100    0.981867         0.981867
# 1                    f        482    0.018133         1.000000

# %%
table7_7= table7.drop(['percentage', 'cumulative_perc'], axis=1)
table7_7
# Out:
#   host_has_profile_pic  frequency
# 0                    t      26100
# 1                    f        482

# %%
Filtro7=table7_7[table7_7['frequency']>1]
Filtro7
# Out:
#   host_has_profile_pic  frequency
# 0                    t      26100
# 1                    f        482

# %%
Filtro_index7= Filtro7.set_index('host_has_profile_pic')
Filtro_index7
# Out:
#                       frequency
# host_has_profile_pic
# t                         26100
# f                           482

# %%
Filtro_index7["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 8 Análisis univariado de una variable categorica: 'host_identity_verified'

# %%
table8=freq_tbl(Micro_Retailer['host_identity_verified'])
table8
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t      25426    0.956512         0.956512
# 1                      f       1156    0.043488         1.000000

# %%
table8_8= table8.drop(['percentage', 'cumulative_perc'], axis=1)
table8_8
# Out:
#   host_identity_verified  frequency
# 0                      t      25426
# 1                      f       1156

# %%
Filtro_index8= table8_8.set_index('host_identity_verified')
Filtro_index8
# Out:
#                         frequency
# host_identity_verified
# t                           25426
# f                            1156

# %%
Filtro_index8["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 9 Análisis univariado de una variable categorica: 'property_type'

# %%
table9=freq_tbl(Micro_Retailer['property_type'])
table9
# Out:
#                   property_type  frequency  percentage  cumulative_perc
# 0            Entire rental unit       9971    0.375103         0.375103
# 1                  Entire condo       3423    0.128771         0.503875
# 2   Private room in rental unit       3034    0.114137         0.618012
# 3          Private room in home       2266    0.085246         0.703258
# 4                   Entire loft       1515    0.056993         0.760251
# ..                          ...        ...         ...              ...
# 87    Private room in houseboat          1    0.000038         0.999850
# 88                         Boat          1    0.000038         0.999887
# 89       Private room in resort          1    0.000038         0.999925
# 90        Private room in minsu          1    0.000038         0.999962
# 91                        Tower          1    0.000038         1.000000
#
# [92 rows x 4 columns]

# %%
table9_9= table9.drop(['percentage', 'cumulative_perc'], axis=1)
table9_9
# Out:
#                   property_type  frequency
# 0            Entire rental unit       9971
# 1                  Entire condo       3423
# 2   Private room in rental unit       3034
# 3          Private room in home       2266
# 4                   Entire loft       1515
# ..                          ...        ...
# 87    Private room in houseboat          1
# 88                         Boat          1
# 89       Private room in resort          1
# 90        Private room in minsu          1
# 91                        Tower          1
#
# [92 rows x 2 columns]

# %%
Filtro9=table9_9[table9_9['frequency']>87]
Filtro9
# Out:
#                          property_type  frequency
# 0                   Entire rental unit       9971
# 1                         Entire condo       3423
# 2          Private room in rental unit       3034
# 3                 Private room in home       2266
# 4                          Entire loft       1515
# 5                Private room in condo        846
# 6            Entire serviced apartment        846
# 7                          Entire home        817
# 8                        Room in hotel        504
# 9           Private room in guesthouse        381
# 10  Private room in serviced apartment        284
# 11         Private room in guest suite        276
# 12   Private room in bed and breakfast        269
# 13                  Entire guest suite        241
# 14     Private room in casa particular        211
# 15              Room in boutique hotel        174
# 16                Private room in loft        130
# 17                 Shared room in home        111
# ...

# %%
Filtro_index9= Filtro9.set_index('property_type')
Filtro_index9
# Out:
#                                     frequency
# property_type
# Entire rental unit                       9971
# Entire condo                             3423
# Private room in rental unit              3034
# Private room in home                     2266
# Entire loft                              1515
# Private room in condo                     846
# Entire serviced apartment                 846
# Entire home                               817
# Room in hotel                             504
# Private room in guesthouse                381
# Private room in serviced apartment        284
# Private room in guest suite               276
# Private room in bed and breakfast         269
# Entire guest suite                        241
# Private room in casa particular           211
# Room in boutique hotel                    174
# Private room in loft                      130
# Shared room in home                       111
# Entire guesthouse                         100
# ...

# %%
Filtro_index9.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Tipo de propiedad')
plt.xlabel('Propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 10 Análisis univariado de una variable categorica: 'room_type'

# %%
table10=freq_tbl(Micro_Retailer['room_type'])
table10
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt      17363    0.653186         0.653186
# 1     Private room       8693    0.327026         0.980212
# 2      Shared room        401    0.015085         0.995298
# 3       Hotel room        125    0.004702         1.000000

# %%
table10_10= table10.drop(['percentage', 'cumulative_perc'], axis=1)
table10_10
# Out:
#          room_type  frequency
# 0  Entire home/apt      17363
# 1     Private room       8693
# 2      Shared room        401
# 3       Hotel room        125

# %%
Filtro_index10= table10_10.set_index('room_type')
Filtro_index10
# Out:
#                  frequency
# room_type
# Entire home/apt      17363
# Private room          8693
# Shared room            401
# Hotel room             125

# %%
Filtro_index10.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "grey")
plt.title('Tipo de habitación')
plt.xlabel('Habitación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 11 Análisis univariado de una variable categorica: 'bathrooms_text'

# %%
table11=freq_tbl(Micro_Retailer['bathrooms_text'])
table11
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath      11301    0.425137         0.425137
# 1             2 baths       4606    0.173275         0.598412
# 2      1 private bath       3144    0.118276         0.716688
# 3       1 shared bath       2482    0.093371         0.810059
# 4           1.5 baths       1432    0.053871         0.863930
# 5           2.5 baths        854    0.032127         0.896057
# 6             3 baths        546    0.020540         0.916598
# 7    1.5 shared baths        459    0.017267         0.933865
# 8      2 shared baths        320    0.012038         0.945903
# 9           3.5 baths        250    0.009405         0.955308
# 10            4 baths        186    0.006997         0.962305
# 11   2.5 shared baths        121    0.004552         0.966857
# 12     3 shared baths        105    0.003950         0.970807
# 13          4.5 baths        102    0.003837         0.974644
# ...

# %%
table11_11= table11.drop(['percentage', 'cumulative_perc'], axis=1)
table11_11
# Out:
#        bathrooms_text  frequency
# 0              1 bath      11301
# 1             2 baths       4606
# 2      1 private bath       3144
# 3       1 shared bath       2482
# 4           1.5 baths       1432
# 5           2.5 baths        854
# 6             3 baths        546
# 7    1.5 shared baths        459
# 8      2 shared baths        320
# 9           3.5 baths        250
# 10            4 baths        186
# 11   2.5 shared baths        121
# 12     3 shared baths        105
# 13          4.5 baths        102
# 14     4 shared baths         68
# 15     5 shared baths         54
# 16            0 baths         54
# 17            5 baths         51
# 18     0 shared baths         45
# 19            6 baths         44
# 20          Half-bath         41
# 21          5.5 baths         38
# 22   3.5 shared baths         33
# 23             1 baño         26
# 24            7 baths         25
# 25   Shared half-bath         21
# 26   4.5 shared baths         20
# ...

# %%
Filtro11=table11_11[table11_11['frequency']>106]
Filtro11
# Out:
#       bathrooms_text  frequency
# 0             1 bath      11301
# 1            2 baths       4606
# 2     1 private bath       3144
# 3      1 shared bath       2482
# 4          1.5 baths       1432
# 5          2.5 baths        854
# 6            3 baths        546
# 7   1.5 shared baths        459
# 8     2 shared baths        320
# 9          3.5 baths        250
# 10           4 baths        186
# 11  2.5 shared baths        121

# %%
Filtro_index11= Filtro11.set_index('bathrooms_text')
Filtro_index11
# Out:
#                   frequency
# bathrooms_text
# 1 bath                11301
# 2 baths                4606
# 1 private bath         3144
# 1 shared bath          2482
# 1.5 baths              1432
# 2.5 baths               854
# 3 baths                 546
# 1.5 shared baths        459
# 2 shared baths          320
# 3.5 baths               250
# 4 baths                 186
# 2.5 shared baths        121

# %%
Filtro_index11.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "brown")
plt.title('Descripción de baños')
plt.xlabel('Baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 12 Análisis univariado de una variable categorica: 'has_availability'

# %%
table12=freq_tbl(Micro_Retailer['has_availability'])
table12
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t      25533    0.960537         0.960537
# 1                f       1049    0.039463         1.000000

# %%
table12_12= table12.drop(['percentage', 'cumulative_perc'], axis=1)
table12_12
# Out:
#   has_availability  frequency
# 0                t      25533
# 1                f       1049

# %%
Filtro_index12= table12_12.set_index('has_availability')
Filtro_index12
# Out:
#                   frequency
# has_availability
# t                     25533
# f                      1049

# %%
Filtro_index12["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 13 Análisis univariado de una variable categorica: 'first_review'

# %%
table13=freq_tbl(Micro_Retailer['first_review'])
table13
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0       Sin fecha       3656    0.137537         0.137537
# 1      27/08/2023        105    0.003950         0.141487
# 2      31/10/2022        103    0.003875         0.145362
# 3      30/10/2023         82    0.003085         0.148446
# 4      29/10/2023         82    0.003085         0.151531
# ...           ...        ...         ...              ...
# 3321   12/06/2013          1    0.000038         0.999850
# 3322   13/09/2011          1    0.000038         0.999887
# 3323   07/12/2011          1    0.000038         0.999925
# 3324   10/11/2013          1    0.000038         0.999962
# 3325   01/11/2011          1    0.000038         1.000000
#
# [3326 rows x 4 columns]

# %%
table13_13= table13.drop(['percentage', 'cumulative_perc'], axis=1)
table13_13
# Out:
#      first_review  frequency
# 0       Sin fecha       3656
# 1      27/08/2023        105
# 2      31/10/2022        103
# 3      30/10/2023         82
# 4      29/10/2023         82
# ...           ...        ...
# 3321   12/06/2013          1
# 3322   13/09/2011          1
# 3323   07/12/2011          1
# 3324   10/11/2013          1
# 3325   01/11/2011          1
#
# [3326 rows x 2 columns]

# %%
Filtro13=table13_13[table13_13['frequency']>50]
Filtro13
# Out:
#    first_review  frequency
# 0     Sin fecha       3656
# 1    27/08/2023        105
# 2    31/10/2022        103
# 3    30/10/2023         82
# 4    29/10/2023         82
# 5    30/06/2024         78
# 6    16/09/2024         73
# 7    30/10/2022         64
# 8    19/05/2024         60
# 9    26/02/2024         60
# 10   04/02/2024         56
# 11   25/02/2024         55
# 12   05/11/2023         54
# 13   21/11/2022         53
# 14   11/08/2024         51
# 15   31/10/2023         51

# %%
Filtro_index13= Filtro13.set_index('first_review')
Filtro_index13
# Out:
#               frequency
# first_review
# Sin fecha          3656
# 27/08/2023          105
# 31/10/2022          103
# 30/10/2023           82
# 29/10/2023           82
# 30/06/2024           78
# 16/09/2024           73
# 30/10/2022           64
# 19/05/2024           60
# 26/02/2024           60
# 04/02/2024           56
# 25/02/2024           55
# 05/11/2023           54
# 21/11/2022           53
# 11/08/2024           51
# 31/10/2023           51

# %%
Filtro_index13.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "gold")
plt.title('Fecha de primera reseña')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 14 Análisis univariado de una variable categorica: 'last_review'

# %%
table14=freq_tbl(Micro_Retailer['last_review'])
table14
# Out:
#      last_review  frequency  percentage  cumulative_perc
# 0      Sin fecha       3656    0.137537         0.137537
# 1     22/09/2024       1081    0.040667         0.178203
# 2     16/09/2024       1068    0.040178         0.218381
# 3     23/09/2024        898    0.033782         0.252163
# 4     17/09/2024        711    0.026747         0.278911
# ...          ...        ...         ...              ...
# 1630  17/06/2022          1    0.000038         0.999850
# 1631  29/07/2022          1    0.000038         0.999887
# 1632  01/05/2021          1    0.000038         0.999925
# 1633  26/07/2023          1    0.000038         0.999962
# 1634  03/12/2020          1    0.000038         1.000000
#
# [1635 rows x 4 columns]

# %%
table14_14= table14.drop(['percentage', 'cumulative_perc'], axis=1)
table14_14
# Out:
#      last_review  frequency
# 0      Sin fecha       3656
# 1     22/09/2024       1081
# 2     16/09/2024       1068
# 3     23/09/2024        898
# 4     17/09/2024        711
# ...          ...        ...
# 1630  17/06/2022          1
# 1631  29/07/2022          1
# 1632  01/05/2021          1
# 1633  26/07/2023          1
# 1634  03/12/2020          1
#
# [1635 rows x 2 columns]

# %%
Filtro14=table14_14[table14_14['frequency']>100]
Filtro14
# Out:
#    last_review  frequency
# 0    Sin fecha       3656
# 1   22/09/2024       1081
# 2   16/09/2024       1068
# 3   23/09/2024        898
# 4   17/09/2024        711
# 5   08/09/2024        680
# 6   01/09/2024        537
# 7   21/09/2024        513
# 8   09/09/2024        422
# 9   02/09/2024        387
# 10  18/09/2024        385
# 11  10/09/2024        380
# 12  15/09/2024        379
# 13  20/09/2024        357
# 14  25/08/2024        347
# 15  07/09/2024        339
# 16  19/09/2024        311
# 17  31/08/2024        302
# 18  11/09/2024        243
# 19  24/09/2024        237
# 20  14/09/2024        236
# 21  06/09/2024        230
# 22  30/06/2024        201
# 23  03/09/2024        199
# 24  13/09/2024        195
# 25  30/08/2024        193
# 26  11/08/2024        187
# 27  04/09/2024        186
# 28  18/08/2024        180
# 29  12/09/2024        173
# 30  24/08/2024        164
# 31  26/08/2024        161
# 32  05/09/2024        158
# 33  27/08/2024        119
# ...

# %%
Filtro_index14= Filtro14.set_index('last_review')
Filtro_index14
# Out:
#              frequency
# last_review
# Sin fecha         3656
# 22/09/2024        1081
# 16/09/2024        1068
# 23/09/2024         898
# 17/09/2024         711
# 08/09/2024         680
# 01/09/2024         537
# 21/09/2024         513
# 09/09/2024         422
# 02/09/2024         387
# 18/09/2024         385
# 10/09/2024         380
# 15/09/2024         379
# 20/09/2024         357
# 25/08/2024         347
# 07/09/2024         339
# 19/09/2024         311
# 31/08/2024         302
# 11/09/2024         243
# 24/09/2024         237
# 14/09/2024         236
# 06/09/2024         230
# 30/06/2024         201
# 03/09/2024         199
# 13/09/2024         195
# 30/08/2024         193
# 11/08/2024         187
# 04/09/2024         186
# 18/08/2024         180
# 12/09/2024         173
# 24/08/2024         164
# 26/08/2024         161
# 05/09/2024         158
# 27/08/2024         119
# 23/08/2024         115
# 12/08/2024         113
# 17/08/2024         112
# 04/08/2024         109
# ...

# %%
Filtro_index14.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Fecha de ultima reseña')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 15 Análisis univariado de una variable categorica: 'license'

# %%
table15=freq_tbl(Micro_Retailer['license'])
table15
# Out:
#         license  frequency  percentage  cumulative_perc
# 0  Sin licencia      26582         1.0              1.0

# %%
table15_15= table15.drop(['percentage', 'cumulative_perc'], axis=1)
table15_15
# Out:
#         license  frequency
# 0  Sin licencia      26582

# %%
Filtro15=table15_15[table15_15['frequency']>15]
Filtro15
# Out:
#         license  frequency
# 0  Sin licencia      26582

# %%
Filtro_index15= Filtro15.set_index('license')
Filtro_index15
# Out:
#               frequency
# license
# Sin licencia      26582

# %%
Filtro_index15.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Licencia')
plt.xlabel('Licencia')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 16 Análisis univariado de una variable categorica: 'instant_bookable'

# %%
table16=freq_tbl(Micro_Retailer['instant_bookable'])
table16
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f      16080    0.604921         0.604921
# 1                t      10502    0.395079         1.000000

# %%
table16_16= table16.drop(['percentage', 'cumulative_perc'], axis=1)
table16_16
# Out:
#   instant_bookable  frequency
# 0                f      16080
# 1                t      10502

# %%
Filtro_index16= table16_16.set_index('instant_bookable')
Filtro_index16
# Out:
#                   frequency
# instant_bookable
# f                     16080
# t                     10502

# %%
Filtro_index16["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 17 Análisis univariado de una variable categorica: 'host_id'

# %%
Micro_Retailer['host_id'] = Micro_Retailer['host_id'].astype(str)

# %%
table17=freq_tbl(Micro_Retailer['host_id'])
table17
# Out:
#          host_id  frequency  percentage  cumulative_perc
# 0      498701635        258    0.009706         0.009706
# 1       10764020        216    0.008126         0.017832
# 2      333035396        177    0.006659         0.024490
# 3      539407308        170    0.006395         0.030886
# 4       16148871        148    0.005568         0.036453
# ...          ...        ...         ...              ...
# 12087   72755819          1    0.000038         0.999850
# 12088  650430700          1    0.000038         0.999887
# 12089   11143895          1    0.000038         0.999925
# 12090   81993856          1    0.000038         0.999962
# 12091   26689305          1    0.000038         1.000000
#
# [12092 rows x 4 columns]

# %%
table17_17= table17.drop(['percentage', 'cumulative_perc'], axis=1)
table17_17
# Out:
#          host_id  frequency
# 0      498701635        258
# 1       10764020        216
# 2      333035396        177
# 3      539407308        170
# 4       16148871        148
# ...          ...        ...
# 12087   72755819          1
# 12088  650430700          1
# 12089   11143895          1
# 12090   81993856          1
# 12091   26689305          1
#
# [12092 rows x 2 columns]

# %%
Filtro17=table17_17[table17_17['frequency']>50]
Filtro17
# Out:
#       host_id  frequency
# 0   498701635        258
# 1    10764020        216
# 2   333035396        177
# 3   539407308        170
# 4    16148871        148
# 5   207240505        115
# 6    91265490        109
# 7   245618000        103
# 8   302431514         89
# 9    50305161         88
# 10   27449159         81
# 11   23468816         75
# 12   94011901         63
# 13  497726424         61
# 14  276377520         60
# 15  348389387         55
# 16   15359500         53
# 17  150617712         51

# %%
Filtro_index17= Filtro17.set_index('host_id')
Filtro_index17
# Out:
#            frequency
# host_id
# 498701635        258
# 10764020         216
# 333035396        177
# 539407308        170
# 16148871         148
# 207240505        115
# 91265490         109
# 245618000        103
# 302431514         89
# 50305161          88
# 27449159          81
# 23468816          75
# 94011901          63
# 497726424         61
# 276377520         60
# 348389387         55
# 15359500          53
# 150617712         51

# %%
Filtro_index17.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Número de identificación')
plt.xlabel('ID')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 18 Análisis univariado de una variable categorica: 'maximum_nights'

# %%
Micro_Retailer['maximum_nights'] = Micro_Retailer['maximum_nights'].astype(str)

# %%
table18=freq_tbl(Micro_Retailer['maximum_nights'])
table18
# Out:
#     maximum_nights  frequency  percentage  cumulative_perc
# 0              365      10638    0.400196         0.400196
# 1             1125       7983    0.300316         0.700512
# 2               30       1271    0.047814         0.748326
# 3               90        932    0.035061         0.783387
# 4               60        742    0.027914         0.811301
# ..             ...        ...         ...              ...
# 186            174          1    0.000038         0.999850
# 187            708          1    0.000038         0.999887
# 188             38          1    0.000038         0.999925
# 189            235          1    0.000038         0.999962
# 190             66          1    0.000038         1.000000
#
# [191 rows x 4 columns]

# %%
table18_18= table18.drop(['percentage', 'cumulative_perc'], axis=1)
table18_18
# Out:
#     maximum_nights  frequency
# 0              365      10638
# 1             1125       7983
# 2               30       1271
# 3               90        932
# 4               60        742
# ..             ...        ...
# 186            174          1
# 187            708          1
# 188             38          1
# 189            235          1
# 190             66          1
#
# [191 rows x 2 columns]

# %%
Filtro18=table18_18[table18_18['frequency']>136]
Filtro18
# Out:
#    maximum_nights  frequency
# 0             365      10638
# 1            1125       7983
# 2              30       1271
# 3              90        932
# 4              60        742
# 5             730        462
# 6             180        428
# 7              15        387
# 8              28        347
# 9             120        296
# 10             31        273
# 11              7        225
# 12             20        148
# 13             45        140

# %%
Filtro_index18= Filtro18.set_index('maximum_nights')
Filtro_index18
# Out:
#                 frequency
# maximum_nights
# 365                 10638
# 1125                 7983
# 30                   1271
# 90                    932
# 60                    742
# 730                   462
# 180                   428
# 15                    387
# 28                    347
# 120                   296
# 31                    273
# 7                     225
# 20                    148
# 45                    140

# %%
Filtro_index18.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Número maximo de noches')
plt.xlabel('Noches')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 19 Análisis univariado de una variable categorica: ' availability_365'

# %%
Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].astype(str)

# %%
table19=freq_tbl(Micro_Retailer['availability_365'])
table19
# Out:
#     availability_365  frequency  percentage  cumulative_perc
# 0                  0       2360    0.088782         0.088782
# 1                365       1253    0.047137         0.135919
# 2                364        715    0.026898         0.162817
# 3                269        450    0.016929         0.179746
# 4                363        396    0.014897         0.194643
# ..               ...        ...         ...              ...
# 361               11         11    0.000414         0.998759
# 362              181         10    0.000376         0.999135
# 363              189          8    0.000301         0.999436
# 364              193          8    0.000301         0.999737
# 365              182          7    0.000263         1.000000
#
# [366 rows x 4 columns]

# %%
table19_19= table19.drop(['percentage', 'cumulative_perc'], axis=1)
table19_19
# Out:
#     availability_365  frequency
# 0                  0       2360
# 1                365       1253
# 2                364        715
# 3                269        450
# 4                363        396
# ..               ...        ...
# 361               11         11
# 362              181         10
# 363              189          8
# 364              193          8
# 365              182          7
#
# [366 rows x 2 columns]

# %%
Filtro19=table19_19[table19_19['frequency']>150]
Filtro19
# Out:
#    availability_365  frequency
# 0                 0       2360
# 1               365       1253
# 2               364        715
# 3               269        450
# 4               363        396
# 5               267        382
# 6               359        348
# 7               362        320
# 8               360        287
# 9               361        262
# 10              328        255
# 11              358        248
# 12              270        217
# 13              356        200
# 14               89        197
# 15              357        195
# 16              354        187
# 17              179        184
# 18              329        182
# 19              268        179
# 20              353        175
# 21              349        172
# 22              348        168
# 23              352        164
# 24              347        164
# 25              355        163
# 26              345        161
# 27              351        161
# 28               90        159
# ...

# %%
Filtro_index19= Filtro19.set_index('availability_365')
Filtro_index19
# Out:
#                   frequency
# availability_365
# 0                      2360
# 365                    1253
# 364                     715
# 269                     450
# 363                     396
# 267                     382
# 359                     348
# 362                     320
# 360                     287
# 361                     262
# 328                     255
# 358                     248
# 270                     217
# 356                     200
# 89                      197
# 357                     195
# 354                     187
# 179                     184
# 329                     182
# 268                     179
# 353                     175
# 349                     172
# 348                     168
# 352                     164
# 347                     164
# 355                     163
# 345                     161
# 351                     161
# 90                      159
# 346                     155

# %%
Filtro_index19.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "blue")
plt.title('Noches disponibles en 365 días')
plt.xlabel('Noches')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 20 Análisis univariado de una variable categorica: 'availability_30'

# %%
Micro_Retailer['availability_30'] = Micro_Retailer['availability_30'].astype(str)

# %%
table20=freq_tbl(Micro_Retailer['availability_30'])
table20
# Out:
#    availability_30  frequency  percentage  cumulative_perc
# 0                0       6274    0.236024         0.236024
# 1               30       2538    0.095478         0.331503
# 2               29       1495    0.056241         0.387744
# 3               28        980    0.036867         0.424611
# 4               24        909    0.034196         0.458807
# 5               27        899    0.033820         0.492627
# 6               25        813    0.030585         0.523211
# 7               26        809    0.030434         0.553645
# 8               23        782    0.029418         0.583064
# 9               22        644    0.024227         0.607291
# 10              21        629    0.023663         0.630953
# 11              19        593    0.022308         0.653262
# 12              17        588    0.022120         0.675382
# 13              20        586    0.022045         0.697427
# 14              13        564    0.021217         0.718644
# ...

# %%
table20_20= table20.drop(['percentage', 'cumulative_perc'], axis=1)
table20_20
# Out:
#    availability_30  frequency
# 0                0       6274
# 1               30       2538
# 2               29       1495
# 3               28        980
# 4               24        909
# 5               27        899
# 6               25        813
# 7               26        809
# 8               23        782
# 9               22        644
# 10              21        629
# 11              19        593
# 12              17        588
# 13              20        586
# 14              13        564
# 15              18        550
# 16              14        545
# 17              16        538
# 18              12        534
# 19              15        524
# 20               9        510
# 21               1        488
# 22               6        483
# 23              10        477
# 24              11        471
# 25               8        456
# 26               7        444
# 27               5        384
# 28               2        371
# 29               3        353
# ...

# %%
Filtro20=table20_20[table20_20['frequency']>9]
Filtro20
# Out:
#    availability_30  frequency
# 0                0       6274
# 1               30       2538
# 2               29       1495
# 3               28        980
# 4               24        909
# 5               27        899
# 6               25        813
# 7               26        809
# 8               23        782
# 9               22        644
# 10              21        629
# 11              19        593
# 12              17        588
# 13              20        586
# 14              13        564
# 15              18        550
# 16              14        545
# 17              16        538
# 18              12        534
# 19              15        524
# 20               9        510
# 21               1        488
# 22               6        483
# 23              10        477
# 24              11        471
# 25               8        456
# 26               7        444
# 27               5        384
# 28               2        371
# 29               3        353
# ...

# %%
Filtro_index20= Filtro20.set_index('availability_30')
Filtro_index20
# Out:
#                  frequency
# availability_30
# 0                     6274
# 30                    2538
# 29                    1495
# 28                     980
# 24                     909
# 27                     899
# 25                     813
# 26                     809
# 23                     782
# 22                     644
# 21                     629
# 19                     593
# 17                     588
# 20                     586
# 13                     564
# 18                     550
# 14                     545
# 16                     538
# 12                     534
# 15                     524
# 9                      510
# 1                      488
# 6                      483
# 10                     477
# 11                     471
# 8                      456
# 7                      444
# 5                      384
# 2                      371
# 3                      353
# 4                      351

# %%
Filtro_index20.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Noches disponibles en 30 días')
plt.xlabel('Noches')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# CATEGORIZACIÓN DE VARIABLES

# %% [markdown]
# Categorización de variable 'host_acceptance_rate'

# %%
Micro_Retailer['host_acceptance_rate']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['host_acceptance_rate'].max()
Min=Micro_Retailer['host_acceptance_rate'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(74.0), np.float64(100.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(26.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
i=R/ni
i
# Out:
# np.float64(1.85635471082795)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([ 74.  ,  77.25,  80.5 ,  83.75,  87.  ,  90.25,  93.5 ,  96.75,
#        100.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['host_acceptance_rate']=pd.cut(x= Micro_Retailer['host_acceptance_rate'], bins=intervalos, labels=categorias)
Micro_Retailer['host_acceptance_rate']
# Out:
# 0        Categoria5
# 1        Categoria6
# 2        Categoria7
# 3        Categoria8
# 4        Categoria8
#             ...
# 26577    Categoria8
# 26578    Categoria8
# 26579    Categoria8
# 26580    Categoria8
# 26581    Categoria8
# Name: host_acceptance_rate, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
print(Micro_Retailer['host_acceptance_rate'].unique())
# Out:
# ['Categoria5', 'Categoria6', 'Categoria7', 'Categoria8', 'Categoria2', 'Categoria1', 'Categoria3', 'Categoria4', NaN]
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['host_acceptance_rate'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Tasa de aceptación del anfitrión')
plt.xlabel('Aceptación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'host_total_listings_count'

# %%
Micro_Retailer['host_total_listings_count']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['host_total_listings_count'].max()
Min=Micro_Retailer['host_total_listings_count'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(1.0), np.float64(39.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(38.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([ 1.  ,  5.75, 10.5 , 15.25, 20.  , 24.75, 29.5 , 34.25, 39.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['host_total_listings_count']=pd.cut(x= Micro_Retailer['host_total_listings_count'], bins=intervalos, labels=categorias)
Micro_Retailer['host_total_listings_count']
# Out:
# 0               NaN
# 1        Categoria3
# 2        Categoria1
# 3        Categoria1
# 4        Categoria2
#             ...
# 26577    Categoria2
# 26578    Categoria4
# 26579    Categoria4
# 26580    Categoria4
# 26581    Categoria2
# Name: host_total_listings_count, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['host_total_listings_count'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Total de propiedades del anfitrión')
plt.xlabel('Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'accommodates'

# %%
Micro_Retailer['accommodates']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['accommodates'].max()
Min=Micro_Retailer['accommodates'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(1.0), np.float64(7.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(6.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([1.  , 1.75, 2.5 , 3.25, 4.  , 4.75, 5.5 , 6.25, 7.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['accommodates']=pd.cut(x= Micro_Retailer['accommodates'], bins=intervalos, labels=categorias)
Micro_Retailer['accommodates']
# Out:
# 0        Categoria2
# 1        Categoria3
# 2        Categoria4
# 3        Categoria2
# 4        Categoria2
#             ...
# 26577    Categoria4
# 26578    Categoria2
# 26579    Categoria2
# 26580    Categoria2
# 26581    Categoria2
# Name: accommodates, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['accommodates'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Capacidad maxima')
plt.xlabel('Capacidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'bathrooms_text'

# %%
Micro_Retailer['bathrooms_text'] = Micro_Retailer['bathrooms_text'].str.extract('(\d+)')
# Convertir a float
Micro_Retailer['bathrooms_text'] = Micro_Retailer['bathrooms_text'].astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\yack_\AppData\Local\Temp\ipykernel_26460\2327146491.py:1: SyntaxWarning: invalid escape sequence '\d'
#   Micro_Retailer['bathrooms_text'] = Micro_Retailer['bathrooms_text'].str.extract('(\d+)')

# %%
Micro_Retailer['bathrooms_text']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 26510 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['bathrooms_text'].max()
Min=Micro_Retailer['bathrooms_text'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(49.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(49.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 6)
intervalos
# Out:
# array([ 0. ,  9.8, 19.6, 29.4, 39.2, 49. ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5"]

# %%
Micro_Retailer['bathrooms_text']=pd.cut(x= Micro_Retailer['bathrooms_text'], bins=intervalos, labels=categorias)
Micro_Retailer['bathrooms_text']
# Out:
# 0        Categoria1
# 1        Categoria1
# 2        Categoria1
# 3        Categoria1
# 4        Categoria1
#             ...
# 26577    Categoria1
# 26578    Categoria1
# 26579    Categoria1
# 26580    Categoria1
# 26581    Categoria1
# Name: bathrooms_text, Length: 26582, dtype: category
# Categories (5, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5']

# %%
Micro_Retailer['bathrooms_text'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "blue")
plt.title('Número de baños')
plt.xlabel('Baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'beds'

# %%
Micro_Retailer['beds']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['beds'].max()
Min=Micro_Retailer['beds'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(3.0)]

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([0.   , 0.375, 0.75 , 1.125, 1.5  , 1.875, 2.25 , 2.625, 3.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['beds']=pd.cut(x= Micro_Retailer['beds'], bins=intervalos, labels=categorias)
Micro_Retailer['beds']
# Out:
# 0        Categoria3
# 1        Categoria3
# 2        Categoria6
# 3        Categoria3
# 4        Categoria3
#             ...
# 26577    Categoria6
# 26578    Categoria3
# 26579    Categoria3
# 26580    Categoria3
# 26581    Categoria3
# Name: beds, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['beds'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Número de camas')
plt.xlabel('Camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'price'

# %%
Micro_Retailer['price']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['price'].max()
Min=Micro_Retailer['price'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(2713.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(2713.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([   0.   ,  339.125,  678.25 , 1017.375, 1356.5  , 1695.625,
#        2034.75 , 2373.875, 2713.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['price']=pd.cut(x= Micro_Retailer['price'], bins=intervalos, labels=categorias)
Micro_Retailer['price']
# Out:
# 0        Categoria4
# 1        Categoria3
# 2        Categoria6
# 3        Categoria4
# 4        Categoria4
#             ...
# 26577    Categoria2
# 26578    Categoria4
# 26579    Categoria8
# 26580    Categoria8
# 26581    Categoria4
# Name: price, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['price'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "gold")
plt.title('Precio')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'availability_365'

# %%
Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].str.extract('(\d+)')

# Convertir a float
Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\yack_\AppData\Local\Temp\ipykernel_26460\176713607.py:1: SyntaxWarning: invalid escape sequence '\d'
#   Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].str.extract('(\d+)')

# %%
Micro_Retailer['availability_365']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['availability_365'].max()
Min=Micro_Retailer['availability_365'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(365.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(365.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([  0.   ,  45.625,  91.25 , 136.875, 182.5  , 228.125, 273.75 ,
#        319.375, 365.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['availability_365']=pd.cut(x= Micro_Retailer['availability_365'], bins=intervalos, labels=categorias)
Micro_Retailer['availability_365']
# Out:
# 0        Categoria8
# 1        Categoria8
# 2        Categoria8
# 3        Categoria6
# 4        Categoria7
#             ...
# 26577    Categoria8
# 26578    Categoria4
# 26579    Categoria4
# 26580    Categoria4
# 26581    Categoria4
# Name: availability_365, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['availability_365'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Disponibilidad en 365 días')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'number_of_reviews'

# %%
Micro_Retailer['number_of_reviews']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['number_of_reviews'].max()
Min=Micro_Retailer['number_of_reviews'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(135.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(135.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([  0.   ,  16.875,  33.75 ,  50.625,  67.5  ,  84.375, 101.25 ,
#        118.125, 135.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['number_of_reviews']=pd.cut(x= Micro_Retailer['number_of_reviews'], bins=intervalos, labels=categorias)
Micro_Retailer['number_of_reviews']
# Out:
# 0               NaN
# 1        Categoria4
# 2        Categoria3
# 3        Categoria8
# 4        Categoria1
#             ...
# 26577           NaN
# 26578           NaN
# 26579           NaN
# 26580           NaN
# 26581           NaN
# Name: number_of_reviews, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['number_of_reviews'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Reseñas')
plt.xlabel('Número de reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_location'

# %%
Micro_Retailer['review_scores_location']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['review_scores_location'].max()
Min=Micro_Retailer['review_scores_location'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.58), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.41999999999999993)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.58  , 4.6325, 4.685 , 4.7375, 4.79  , 4.8425, 4.895 , 4.9475,
#        5.    ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_location']=pd.cut(x= Micro_Retailer['review_scores_location'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_location']
# Out:
# 0        Categoria6
# 1        Categoria8
# 2        Categoria8
# 3        Categoria8
# 4        Categoria7
#             ...
# 26577    Categoria6
# 26578    Categoria6
# 26579    Categoria6
# 26580    Categoria6
# 26581    Categoria6
# Name: review_scores_location, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_location'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Ubicación')
plt.xlabel('Valor de ubicación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'reviews_per_month'

# %%
Micro_Retailer['reviews_per_month']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['reviews_per_month'].max()
Min=Micro_Retailer['reviews_per_month'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.01), np.float64(4.72)]

# %%
R=Max-Min
R
# Out:
# np.float64(4.71)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([0.01   , 0.59875, 1.1875 , 1.77625, 2.365  , 2.95375, 3.5425 ,
#        4.13125, 4.72   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['reviews_per_month']=pd.cut(x= Micro_Retailer['reviews_per_month'], bins=intervalos, labels=categorias)
Micro_Retailer['reviews_per_month']
# Out:
# 0        Categoria3
# 1        Categoria1
# 2        Categoria1
# 3        Categoria2
# 4        Categoria1
#             ...
# 26577    Categoria3
# 26578    Categoria3
# 26579    Categoria3
# 26580    Categoria3
# 26581    Categoria3
# Name: reviews_per_month, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['reviews_per_month'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Reseñas por mes')
plt.xlabel('Reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_communication'

# %%
Micro_Retailer['review_scores_communication']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['review_scores_communication'].max()
Min=Micro_Retailer['review_scores_communication'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.58), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.41999999999999993)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.58  , 4.6325, 4.685 , 4.7375, 4.79  , 4.8425, 4.895 , 4.9475,
#        5.    ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_communication']=pd.cut(x= Micro_Retailer['review_scores_communication'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_communication']
# Out:
# 0        Categoria5
# 1        Categoria4
# 2        Categoria7
# 3        Categoria8
# 4        Categoria3
#             ...
# 26577    Categoria5
# 26578    Categoria5
# 26579    Categoria5
# 26580    Categoria5
# 26581    Categoria5
# Name: review_scores_communication, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_communication'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Valoración de comunicación')
plt.xlabel('Valoración')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_checkin'

# %%
Micro_Retailer['review_scores_checkin']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['review_scores_checkin'].max()
Min=Micro_Retailer['review_scores_checkin'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.6), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.40000000000000036)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 , 4.95, 5.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_checkin']=pd.cut(x= Micro_Retailer['review_scores_checkin'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_checkin']
# Out:
# 0        Categoria5
# 1        Categoria6
# 2        Categoria7
# 3        Categoria8
# 4        Categoria8
#             ...
# 26577    Categoria5
# 26578    Categoria5
# 26579    Categoria5
# 26580    Categoria5
# 26581    Categoria5
# Name: review_scores_checkin, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_checkin'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "gold")
plt.title('Entrada')
plt.xlabel('Valoración de entrada')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_cleanliness'

# %%
Micro_Retailer['review_scores_cleanliness']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['review_scores_cleanliness'].max()
Min=Micro_Retailer['review_scores_cleanliness'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.43), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.5700000000000003)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.43   , 4.50125, 4.5725 , 4.64375, 4.715  , 4.78625, 4.8575 ,
#        4.92875, 5.     ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_cleanliness']=pd.cut(x= Micro_Retailer['review_scores_cleanliness'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_cleanliness']
# Out:
# 0        Categoria5
# 1        Categoria4
# 2        Categoria5
# 3        Categoria8
# 4        Categoria8
#             ...
# 26577    Categoria5
# 26578    Categoria5
# 26579    Categoria5
# 26580    Categoria5
# 26581    Categoria5
# Name: review_scores_cleanliness, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_cleanliness'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "orange")
plt.title('Limpieza')
plt.xlabel('Valoración de limpieza')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_accuracy'

# %%
Micro_Retailer['review_scores_accuracy']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 26582 entries, 0 to 26581
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 26582 non-null  float64
# dtypes: float64(1)
# memory usage: 207.8 KB

# %%
Max=Micro_Retailer['review_scores_accuracy'].max()
Min=Micro_Retailer['review_scores_accuracy'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.52), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.4800000000000004)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.52, 4.58, 4.64, 4.7 , 4.76, 4.82, 4.88, 4.94, 5.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_accuracy']=pd.cut(x= Micro_Retailer['review_scores_accuracy'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_accuracy']
# Out:
# 0        Categoria5
# 1        Categoria1
# 2        Categoria5
# 3        Categoria7
# 4        Categoria8
#             ...
# 26577    Categoria5
# 26578    Categoria5
# 26579    Categoria5
# 26580    Categoria5
# 26581    Categoria5
# Name: review_scores_accuracy, Length: 26582, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_accuracy'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "grey")
plt.title('Descripción')
plt.xlabel('Valoración de descripción')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
Micro_Retailer=pd.read_csv("Datos_limpios_chicago.csv")
#Lectura de csv

# %%
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8269 entries, 0 to 8268
# Data columns (total 52 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0.1                                  8269 non-null   int64
#  1   listing_url                                   8269 non-null   object
#  2   host_name                                     8269 non-null   object
#  3   host_since                                    8269 non-null   object
#  4   host_location                                 8269 non-null   object
#  5   host_response_time                            8269 non-null   object
#  6   host_is_superhost                             8269 non-null   object
#  7   host_verifications                            8269 non-null   object
#  8   host_has_profile_pic                          8269 non-null   object
#  9   host_identity_verified                        8269 non-null   object
#  10  property_type                                 8269 non-null   object
#  11  room_type                                     8269 non-null   object
#  12  bathrooms_text                                8230 non-null   category
#  13  amenities                                     8269 non-null   object
#  14  calendar_updated                              8269 non-null   object
#  15  has_availability                              8269 non-null   object
#  16  first_review                                  8269 non-null   object
#  17  last_review                                   8269 non-null   object
#  18  license                                       8269 non-null   object
#  19  instant_bookable                              8269 non-null   object
#  20  Unnamed: 0                                    8269 non-null   int64
#  21  id                                            8269 non-null   float64
#  22  host_id                                       8269 non-null   object
#  23  host_response_rate                            8269 non-null   float64
#  24  host_acceptance_rate                          8226 non-null   category
#  25  host_total_listings_count                     6782 non-null   category
#  26  latitude                                      8269 non-null   float64
#  27  longitude                                     8269 non-null   float64
#  28  accommodates                                  7833 non-null   category
#  29  bathrooms                                     8269 non-null   float64
#  30  bedrooms                                      8269 non-null   float64
#  31  beds                                          8124 non-null   category
#  32  price                                         8266 non-null   category
#  33  minimum_nights                                8269 non-null   float64
#  34  maximum_nights                                8269 non-null   object
#  35  availability_30                               8269 non-null   object
#  36  availability_365                              8037 non-null   category
#  37  number_of_reviews                             6679 non-null   category
#  38  number_of_reviews_ltm                         8269 non-null   float64
#  39  number_of_reviews_l30d                        8269 non-null   float64
#  40  review_scores_rating                          8269 non-null   float64
#  41  review_scores_accuracy                        8244 non-null   category
#  42  review_scores_cleanliness                     8253 non-null   category
#  43  review_scores_checkin                         8248 non-null   category
#  44  review_scores_communication                   8254 non-null   category
#  45  review_scores_location                        8250 non-null   category
#  46  review_scores_value                           8269 non-null   float64
#  47  calculated_host_listings_count                8269 non-null   float64
#  48  calculated_host_listings_count_entire_homes   8269 non-null   float64
#  49  calculated_host_listings_count_private_rooms  8269 non-null   float64
#  50  calculated_host_listings_count_shared_rooms   8269 non-null   float64
#  51  reviews_per_month                             8264 non-null   category
# dtypes: category(14), float64(15), int64(2), object(21)
# memory usage: 2.5+ MB

# %%
freq_tbl(Micro_Retailer)
# Out:
#                                            listing_url  ...  cumulative_perc
# 0     https://www.airbnb.com/rooms/1247067926762205766  ...         0.000121
# 1                    https://www.airbnb.com/rooms/2384  ...         0.000242
# 2                    https://www.airbnb.com/rooms/7126  ...         0.000363
# 3                   https://www.airbnb.com/rooms/10945  ...         0.000484
# 4                   https://www.airbnb.com/rooms/12140  ...         0.000605
# ...                                                ...  ...              ...
# 8264               https://www.airbnb.com/rooms/289689  ...         0.999516
# 8265               https://www.airbnb.com/rooms/264547  ...         0.999637
# 8266               https://www.airbnb.com/rooms/250354  ...         0.999758
# 8267               https://www.airbnb.com/rooms/233933  ...         0.999879
# 8268               https://www.airbnb.com/rooms/225314  ...         1.000000
#
# [8269 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#               host_name  frequency  percentage  cumulative_perc
# 0            Blueground        516    0.062402         0.062402
# 1     LuxurybookingsFZE        118    0.014270         0.076672
# 2             RoomPicks        112    0.013545         0.090216
# 3                 Level         83    0.010037         0.100254
# 4                Cloud9         83    0.010037         0.110291
# ...                 ...        ...         ...              ...
# 2042            Delilah          1    0.000121         0.999516
# 2043              Viren          1    0.000121         0.999637
# 2044            Neftali          1    0.000121         0.999758
# 2045              Ciera          1    0.000121         0.999879
# 2046               Otto          1    0.000121         1.000000
#
# [2047 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#       host_since  frequency  percentage  cumulative_perc
# 0     16/12/2016        517    0.062523         0.062523
# 1     25/02/2022        118    0.014270         0.076793
# 2     20/02/2023        108    0.013061         0.089854
# 3     14/03/2019         84    0.010158         0.100012
# 4     04/04/2021         67    0.008103         0.108115
# ...          ...        ...         ...              ...
# 2405  08/12/2014          1    0.000121         0.999516
# 2406  15/02/2015          1    0.000121         0.999637
# 2407  25/07/2009          1    0.000121         0.999758
# 2408  18/10/2009          1    0.000121         0.999879
# 2409  19/05/2009          1    0.000121         1.000000
#
# [2410 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                    host_location  frequency  percentage  cumulative_perc
# 0                    Chicago, IL       5399    0.652921         0.652921
# 1                    Desconocido       1564    0.189140         0.842061
# 2                   New York, NY        529    0.063974         0.906035
# 3    Dubai, United Arab Emirates        119    0.014391         0.920426
# 4                  United States         70    0.008465         0.928891
# ..                           ...        ...         ...              ...
# 215              Punta Gorda, FL          1    0.000121         0.999516
# 216                Nashville, TN          1    0.000121         0.999637
# 217                  Jackson, WY          1    0.000121         0.999758
# 218          Manila, Philippines          1    0.000121         0.999879
# 219                  Cashton, WI          1    0.000121         1.000000
#
# [220 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       6755    0.816907         0.816907
# 1  within a few hours        623    0.075342         0.892248
# 2         No definido        436    0.052727         0.944975
# 3        within a day        250    0.030233         0.975209
# 4  a few days or more        205    0.024791         1.000000
#
# ----------------------------------------------------------------
#
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       4595     0.55569          0.55569
# 1                 t       3674     0.44431          1.00000
#
# ----------------------------------------------------------------
#
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       6151    0.743863         0.743863
# 1  ['email', 'phone', 'work_email']       1517    0.183456         0.927319
# 2                         ['phone']        533    0.064458         0.991777
# 3           ['phone', 'work_email']         65    0.007861         0.999637
# 4                         ['email']          3    0.000363         1.000000
#
# ----------------------------------------------------------------
#
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t       8116    0.981497         0.981497
# 1                    f        153    0.018503         1.000000
#
# ----------------------------------------------------------------
#
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       7514    0.908695         0.908695
# 1                      f        755    0.091305         1.000000
#
# ----------------------------------------------------------------
#
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       4298    0.519773         0.519773
# 1          Private room in rental unit        732    0.088523         0.608296
# 2                         Entire condo        718    0.086830         0.695126
# 3                          Entire home        711    0.085984         0.781110
# 4                 Private room in home        491    0.059378         0.840489
# 5            Entire serviced apartment        234    0.028298         0.868787
# 6                        Room in hotel        231    0.027936         0.896723
# 7                   Entire guest suite        135    0.016326         0.913049
# 8                Private room in condo        122    0.014754         0.927803
# 9                     Entire townhouse        100    0.012093         0.939896
# 10                         Entire loft         66    0.007982         0.947878
# 11           Private room in townhouse         65    0.007861         0.955738
# 12              Room in boutique hotel         58    0.007014         0.962752
# 13   Private room in bed and breakfast         52    0.006289         0.969041
# 14                   Entire guesthouse         50    0.006047         0.975088
# 15                 Shared room in home         31    0.003749         0.978837
# 16            Private room in bungalow         23    0.002781         0.981618
# 17          Shared room in rental unit         22    0.002661         0.984279
# 18                Private room in loft         18    0.002177         0.986455
# 19                     Entire bungalow         17    0.002056         0.988511
# 20         Private room in guest suite         17    0.002056         0.990567
# 21                Entire vacation home         10    0.001209         0.991777
# 22          Room in serviced apartment          9    0.001088         0.992865
# 23           Room in bed and breakfast          9    0.001088         0.993953
# 24                           Tiny home          6    0.000726         0.994679
# 25                        Entire place          6    0.000726         0.995405
# 26          Private room in guesthouse          5    0.000605         0.996009
# 27              Private room in hostel          3    0.000363         0.996372
# 28                      Entire cottage          3    0.000363         0.996735
# 29               Shared room in hostel          3    0.000363         0.997098
# 30                                Boat          3    0.000363         0.997460
# 31             Private room in cottage          2    0.000242         0.997702
# 32           Private room in farm stay          2    0.000242         0.997944
# 33                  Room in aparthotel          2    0.000242         0.998186
# 34                        Entire villa          2    0.000242         0.998428
# 35     Private room in casa particular          2    0.000242         0.998670
# 36  Private room in serviced apartment          2    0.000242         0.998912
# 37                        Private room          1    0.000121         0.999033
# 38             Shared room in bungalow          1    0.000121         0.999153
# 39                     Casa particular          1    0.000121         0.999274
# 40               Private room in villa          1    0.000121         0.999395
# 41               Private room in minsu          1    0.000121         0.999516
# 42               Private room in tower          1    0.000121         0.999637
# 43                         Shared room          1    0.000121         0.999758
# 44           Shared room in guesthouse          1    0.000121         0.999879
# 45    Shared room in bed and breakfast          1    0.000121         1.000000
#
# ----------------------------------------------------------------
#
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       6360    0.769138         0.769138
# 1     Private room       1731    0.209336         0.978474
# 2       Hotel room        118    0.014270         0.992744
# 3      Shared room         60    0.007256         1.000000
#
# ----------------------------------------------------------------
#
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       4404    0.532592         0.532592
# 1             2 baths       1469    0.177651         0.710243
# 2       1 shared bath        688    0.083202         0.793445
# 3      1 private bath        395    0.047769         0.841214
# 4           1.5 baths        242    0.029266         0.870480
# 5             3 baths        213    0.025759         0.896239
# 6           2.5 baths        208    0.025154         0.921393
# 7      2 shared baths        191    0.023098         0.944491
# 8           3.5 baths        108    0.013061         0.957552
# 9    1.5 shared baths         96    0.011610         0.969162
# 10            4 baths         82    0.009917         0.979078
# 11   2.5 shared baths         21    0.002540         0.981618
# 12     3 shared baths         21    0.002540         0.984158
# 13          4.5 baths         20    0.002419         0.986576
# 14            0 baths         19    0.002298         0.988874
# 15            6 baths         18    0.002177         0.991051
# 16            5 baths         11    0.001330         0.992381
# 17             1 baño         11    0.001330         0.993711
# 18          Half-bath         10    0.001209         0.994921
# 19     0 shared baths          7    0.000847         0.995767
# 20          5.5 baths          4    0.000484         0.996251
# 21            8 baths          4    0.000484         0.996735
# 22          6.5 baths          4    0.000484         0.997219
# 23            9 baths          3    0.000363         0.997581
# 24           10 baths          3    0.000363         0.997944
# 25    11 shared baths          3    0.000363         0.998307
# 26            7 baths          3    0.000363         0.998670
# 27  Private half-bath          2    0.000242         0.998912
# 28          7.5 baths          2    0.000242         0.999153
# 29           12 baths          2    0.000242         0.999395
# 30   Shared half-bath          1    0.000121         0.999516
# 31  11.5 shared baths          1    0.000121         0.999637
# 32          9.5 baths          1    0.000121         0.999758
# 33          8.5 baths          1    0.000121         0.999879
# 34     4 shared baths          1    0.000121         1.000000
#
# ----------------------------------------------------------------
#
#                                               amenities  ...  cumulative_perc
# 0     ["Refrigerator", "Self check-in", "Wifi", "Dis...  ...         0.003507
# 1     ["Refrigerator", "Self check-in", "Wifi", "Dis...  ...         0.006893
# 2     ["Refrigerator", "BBQ grill", "Self check-in",...  ...         0.009675
# 3     ["First aid kit", "Building staff", "Self chec...  ...         0.012335
# 4     ["Paid parking on premises", "First aid kit", ...  ...         0.014996
# ...                                                 ...  ...              ...
# 7337  ["Refrigerator", "Radiant heating", "Backyard"...  ...         0.999516
# 7338  ["Shower gel", "Refrigerator", "BBQ grill", "W...  ...         0.999637
# 7339  ["Shower gel", "Bidet", "Refrigerator", "First...  ...         0.999758
# 7340  ["Shower gel", "First aid kit", "Building staf...  ...         0.999879
# 7341  ["Refrigerator", "BBQ grill", "Radiant heating...  ...         1.000000
#
# [7342 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   calendar_updated  frequency  percentage  cumulative_perc
# 0   No actualizado       8269         1.0              1.0
#
# ----------------------------------------------------------------
#
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       8224    0.994558         0.994558
# 1                f         45    0.005442         1.000000
#
# ----------------------------------------------------------------
#
#      first_review  frequency  percentage  cumulative_perc
# 0       Sin fecha       1590    0.192284         0.192284
# 1      11/08/2024         26    0.003144         0.195429
# 2      17/03/2024         25    0.003023         0.198452
# 3      07/05/2023         25    0.003023         0.201475
# 4      02/09/2024         24    0.002902         0.204378
# ...           ...        ...         ...              ...
# 2310   12/09/2024          1    0.000121         0.999516
# 2311   18/09/2011          1    0.000121         0.999637
# 2312   05/06/2015          1    0.000121         0.999758
# 2313   27/08/2024          1    0.000121         0.999879
# 2314   29/06/2015          1    0.000121         1.000000
#
# [2315 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#     last_review  frequency  percentage  cumulative_perc
# 0     Sin fecha       1590    0.192284         0.192284
# 1    02/09/2024        672    0.081267         0.273552
# 2    01/09/2024        349    0.042206         0.315758
# 3    08/09/2024        312    0.037731         0.353489
# 4    15/09/2024        257    0.031080         0.384569
# ..          ...        ...         ...              ...
# 744  01/03/2020          1    0.000121         0.999516
# 745  16/09/2022          1    0.000121         0.999637
# 746  21/10/2023          1    0.000121         0.999758
# 747  08/03/2024          1    0.000121         0.999879
# 748  06/09/2023          1    0.000121         1.000000
#
# [749 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#                         license  frequency  percentage  cumulative_perc
# 0                  Sin licencia       1692    0.204620         0.204620
# 1     City registration pending        211    0.025517         0.230137
# 2                       2792126        135    0.016326         0.246463
# 3              32+ Days Listing        110    0.013303         0.259765
# 4                       2863615         56    0.006772         0.266538
# ...                         ...        ...         ...              ...
# 4201                    2209984          1    0.000121         0.999516
# 4202               R24000114046          1    0.000121         0.999637
# 4203               R17000015609          1    0.000121         0.999758
# 4204               R24000118819          1    0.000121         0.999879
# 4205               R23000108435          1    0.000121         1.000000
#
# [4206 rows x 4 columns]
#
# ----------------------------------------------------------------
#
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       5218    0.631032         0.631032
# 1                t       3051    0.368968         1.000000
#
# ----------------------------------------------------------------

# %% [markdown]
# 1 Análisis univariado de una variable categorica: 'host_response_time'

# %%
table1=freq_tbl(Micro_Retailer['host_response_time'])
table1
# Out:
#    host_response_time  frequency  percentage  cumulative_perc
# 0      within an hour       6755    0.816907         0.816907
# 1  within a few hours        623    0.075342         0.892248
# 2         No definido        436    0.052727         0.944975
# 3        within a day        250    0.030233         0.975209
# 4  a few days or more        205    0.024791         1.000000

# %%
table1_1= table1.drop(['percentage', 'cumulative_perc'], axis=1)
table1_1
# Out:
#    host_response_time  frequency
# 0      within an hour       6755
# 1  within a few hours        623
# 2         No definido        436
# 3        within a day        250
# 4  a few days or more        205

# %%
Filtro1=table1_1[table1_1['frequency']>1]
Filtro1
# Out:
#    host_response_time  frequency
# 0      within an hour       6755
# 1  within a few hours        623
# 2         No definido        436
# 3        within a day        250
# 4  a few days or more        205

# %%
Filtro_index1= Filtro1.set_index('host_response_time')
Filtro_index1
# Out:
#                     frequency
# host_response_time
# within an hour           6755
# within a few hours        623
# No definido               436
# within a day              250
# a few days or more        205

# %%
Filtro_index1.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Tiempo de respuesta')
plt.xlabel('Respuesta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 2 Análisis univariado de una variable categorica: 'host_name'

# %%
table2=freq_tbl(Micro_Retailer['host_name'])
table2
# Out:
#               host_name  frequency  percentage  cumulative_perc
# 0            Blueground        516    0.062402         0.062402
# 1     LuxurybookingsFZE        118    0.014270         0.076672
# 2             RoomPicks        112    0.013545         0.090216
# 3                 Level         83    0.010037         0.100254
# 4                Cloud9         83    0.010037         0.110291
# ...                 ...        ...         ...              ...
# 2042            Delilah          1    0.000121         0.999516
# 2043              Viren          1    0.000121         0.999637
# 2044            Neftali          1    0.000121         0.999758
# 2045              Ciera          1    0.000121         0.999879
# 2046               Otto          1    0.000121         1.000000
#
# [2047 rows x 4 columns]

# %%
table2_2= table2.drop(['percentage', 'cumulative_perc'], axis=1)
table2_2
# Out:
#               host_name  frequency
# 0            Blueground        516
# 1     LuxurybookingsFZE        118
# 2             RoomPicks        112
# 3                 Level         83
# 4                Cloud9         83
# ...                 ...        ...
# 2042            Delilah          1
# 2043              Viren          1
# 2044            Neftali          1
# 2045              Ciera          1
# 2046               Otto          1
#
# [2047 rows x 2 columns]

# %%
Filtro2=table2_2[table2_2['frequency']>20]
Filtro2
# Out:
#               host_name  frequency
# 0            Blueground        516
# 1     LuxurybookingsFZE        118
# 2             RoomPicks        112
# 3                 Level         83
# 4                Cloud9         83
# ..                  ...        ...
# 59  747 Lofts Concierge         22
# 60             Flexhome         22
# 61               Nicole         21
# 62                 Sara         21
# 63               Justin         21
#
# [64 rows x 2 columns]

# %%
Filtro_index2= Filtro2.set_index('host_name')
Filtro_index2
# Out:
#                      frequency
# host_name
# Blueground                 516
# LuxurybookingsFZE          118
# RoomPicks                  112
# Level                       83
# Cloud9                      83
# ...                        ...
# 747 Lofts Concierge         22
# Flexhome                    22
# Nicole                      21
# Sara                        21
# Justin                      21
#
# [64 rows x 1 columns]

# %%
Filtro_index2.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Nombre del host')
plt.xlabel('Host')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 3 Análisis univariado de una variable categorica: 'host_since'

# %%
table3=freq_tbl(Micro_Retailer['host_since'])
table3
# Out:
#       host_since  frequency  percentage  cumulative_perc
# 0     16/12/2016        517    0.062523         0.062523
# 1     25/02/2022        118    0.014270         0.076793
# 2     20/02/2023        108    0.013061         0.089854
# 3     14/03/2019         84    0.010158         0.100012
# 4     04/04/2021         67    0.008103         0.108115
# ...          ...        ...         ...              ...
# 2405  08/12/2014          1    0.000121         0.999516
# 2406  15/02/2015          1    0.000121         0.999637
# 2407  25/07/2009          1    0.000121         0.999758
# 2408  18/10/2009          1    0.000121         0.999879
# 2409  19/05/2009          1    0.000121         1.000000
#
# [2410 rows x 4 columns]

# %%
table3_3= table3.drop(['percentage', 'cumulative_perc'], axis=1)
table3_3
# Out:
#       host_since  frequency
# 0     16/12/2016        517
# 1     25/02/2022        118
# 2     20/02/2023        108
# 3     14/03/2019         84
# 4     04/04/2021         67
# ...          ...        ...
# 2405  08/12/2014          1
# 2406  15/02/2015          1
# 2407  25/07/2009          1
# 2408  18/10/2009          1
# 2409  19/05/2009          1
#
# [2410 rows x 2 columns]

# %%
Filtro3=table3_3[table3_3['frequency']>20]
Filtro3
# Out:
#     host_since  frequency
# 0   16/12/2016        517
# 1   25/02/2022        118
# 2   20/02/2023        108
# 3   14/03/2019         84
# 4   04/04/2021         67
# 5   07/03/2018         60
# 6   10/03/2021         58
# 7   04/05/2022         52
# 8   07/12/2021         43
# 9   13/02/2019         41
# 10  08/07/2024         38
# 11  24/10/2012         35
# 12  09/04/2021         33
# 13  05/10/2016         33
# 14  16/02/2023         31
# 15  07/08/2016         31
# 16  20/03/2017         31
# 17  09/01/2016         30
# 18  22/05/2019         29
# 19  04/04/2024         29
# 20  22/10/2016         29
# 21  04/03/2024         29
# 22  13/09/2020         29
# 23  01/10/2020         29
# 24  02/12/2020         28
# 25  10/01/2019         28
# 26  25/09/2016         27
# 27  06/11/2023         27
# 28  29/01/2018         26
# 29  12/08/2020         26
# 30  15/06/2022         25
# 31  07/05/2018         25
# 32  16/04/2017         25
# 33  11/09/2015         24
# 34  13/06/2016         24
# 35  23/01/2023         23
# 36  09/06/2011         23
# 37  08/06/2015         23
# 38  08/11/2021         22
# 39  22/01/2018         22
# 40  06/01/2015         22
# 41  25/02/2013         22
# 42  06/04/2021         22
# 43  12/01/2017         21

# %%
Filtro_index3= Filtro3.set_index('host_since')
Filtro_index3
# Out:
#             frequency
# host_since
# 16/12/2016        517
# 25/02/2022        118
# 20/02/2023        108
# 14/03/2019         84
# 04/04/2021         67
# 07/03/2018         60
# 10/03/2021         58
# 04/05/2022         52
# 07/12/2021         43
# 13/02/2019         41
# 08/07/2024         38
# 24/10/2012         35
# 09/04/2021         33
# 05/10/2016         33
# 16/02/2023         31
# 07/08/2016         31
# 20/03/2017         31
# 09/01/2016         30
# 22/05/2019         29
# 04/04/2024         29
# 22/10/2016         29
# 04/03/2024         29
# 13/09/2020         29
# 01/10/2020         29
# 02/12/2020         28
# 10/01/2019         28
# 25/09/2016         27
# 06/11/2023         27
# 29/01/2018         26
# 12/08/2020         26
# 15/06/2022         25
# 07/05/2018         25
# 16/04/2017         25
# 11/09/2015         24
# 13/06/2016         24
# 23/01/2023         23
# 09/06/2011         23
# 08/06/2015         23
# 08/11/2021         22
# 22/01/2018         22
# 06/01/2015         22
# 25/02/2013         22
# 06/04/2021         22
# 12/01/2017         21

# %%
Filtro_index3.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "orange")
plt.title('Fecha inicio de anfitrión')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 4 Análisis univariado de una variable categorica: 'host_location'

# %%
table4=freq_tbl(Micro_Retailer['host_location'])
table4
# Out:
#                    host_location  frequency  percentage  cumulative_perc
# 0                    Chicago, IL       5399    0.652921         0.652921
# 1                    Desconocido       1564    0.189140         0.842061
# 2                   New York, NY        529    0.063974         0.906035
# 3    Dubai, United Arab Emirates        119    0.014391         0.920426
# 4                  United States         70    0.008465         0.928891
# ..                           ...        ...         ...              ...
# 215              Punta Gorda, FL          1    0.000121         0.999516
# 216                Nashville, TN          1    0.000121         0.999637
# 217                  Jackson, WY          1    0.000121         0.999758
# 218          Manila, Philippines          1    0.000121         0.999879
# 219                  Cashton, WI          1    0.000121         1.000000
#
# [220 rows x 4 columns]

# %%
table4_4= table4.drop(['percentage', 'cumulative_perc'], axis=1)
table4_4
# Out:
#                    host_location  frequency
# 0                    Chicago, IL       5399
# 1                    Desconocido       1564
# 2                   New York, NY        529
# 3    Dubai, United Arab Emirates        119
# 4                  United States         70
# ..                           ...        ...
# 215              Punta Gorda, FL          1
# 216                Nashville, TN          1
# 217                  Jackson, WY          1
# 218          Manila, Philippines          1
# 219                  Cashton, WI          1
#
# [220 rows x 2 columns]

# %%
Filtro4=table4_4[table4_4['frequency']>20]
Filtro4
# Out:
#                  host_location  frequency
# 0                  Chicago, IL       5399
# 1                  Desconocido       1564
# 2                 New York, NY        529
# 3  Dubai, United Arab Emirates        119
# 4                United States         70
# 5            San Francisco, CA         50
# 6                   Skokie, IL         41
# 7      Illinois, United States         21

# %%
Filtro_index4= Filtro4.set_index('host_location')
Filtro_index4
# Out:
#                              frequency
# host_location
# Chicago, IL                       5399
# Desconocido                       1564
# New York, NY                       529
# Dubai, United Arab Emirates        119
# United States                       70
# San Francisco, CA                   50
# Skokie, IL                          41
# Illinois, United States             21

# %%
Filtro_index4.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Ubicación de anfitrión')
plt.xlabel('Ubicación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 5 Análisis univariado de una variable categorica: 'host_is_superhost'

# %%
table5=freq_tbl(Micro_Retailer['host_is_superhost'])
table5
# Out:
#   host_is_superhost  frequency  percentage  cumulative_perc
# 0                 f       4595     0.55569          0.55569
# 1                 t       3674     0.44431          1.00000

# %%
table5_5= table5.drop(['percentage', 'cumulative_perc'], axis=1)
table5_5
# Out:
#   host_is_superhost  frequency
# 0                 f       4595
# 1                 t       3674

# %%
Filtro5=table5_5[table5_5['frequency']>1]
Filtro5
# Out:
#   host_is_superhost  frequency
# 0                 f       4595
# 1                 t       3674

# %%
Filtro_index5= Filtro5.set_index('host_is_superhost')
Filtro_index5
# Out:
#                    frequency
# host_is_superhost
# f                       4595
# t                       3674

# %%
Filtro_index5["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 6 Análisis univariado de una variable categorica: 'host_verifications'

# %%
table6=freq_tbl(Micro_Retailer['host_verifications'])
table6
# Out:
#                  host_verifications  frequency  percentage  cumulative_perc
# 0                ['email', 'phone']       6151    0.743863         0.743863
# 1  ['email', 'phone', 'work_email']       1517    0.183456         0.927319
# 2                         ['phone']        533    0.064458         0.991777
# 3           ['phone', 'work_email']         65    0.007861         0.999637
# 4                         ['email']          3    0.000363         1.000000

# %%
table6_6= table6.drop(['percentage', 'cumulative_perc'], axis=1)
table6_6
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       6151
# 1  ['email', 'phone', 'work_email']       1517
# 2                         ['phone']        533
# 3           ['phone', 'work_email']         65
# 4                         ['email']          3

# %%
Filtro6=table6_6[table6_6['frequency']>3]
Filtro6
# Out:
#                  host_verifications  frequency
# 0                ['email', 'phone']       6151
# 1  ['email', 'phone', 'work_email']       1517
# 2                         ['phone']        533
# 3           ['phone', 'work_email']         65

# %%
Filtro_index6= Filtro6.set_index('host_verifications')
Filtro_index6
# Out:
#                                   frequency
# host_verifications
# ['email', 'phone']                     6151
# ['email', 'phone', 'work_email']       1517
# ['phone']                               533
# ['phone', 'work_email']                  65

# %%
Filtro_index6["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 7 Análisis univariado de una variable categorica: 'host_has_profile_pic'

# %%
table7=freq_tbl(Micro_Retailer['host_has_profile_pic'])
table7
# Out:
#   host_has_profile_pic  frequency  percentage  cumulative_perc
# 0                    t       8116    0.981497         0.981497
# 1                    f        153    0.018503         1.000000

# %%
table7_7= table7.drop(['percentage', 'cumulative_perc'], axis=1)
table7_7
# Out:
#   host_has_profile_pic  frequency
# 0                    t       8116
# 1                    f        153

# %%
Filtro7=table7_7[table7_7['frequency']>1]
Filtro7
# Out:
#   host_has_profile_pic  frequency
# 0                    t       8116
# 1                    f        153

# %%
Filtro_index7= Filtro7.set_index('host_has_profile_pic')
Filtro_index7
# Out:
#                       frequency
# host_has_profile_pic
# t                          8116
# f                           153

# %%
Filtro_index7["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 8 Análisis univariado de una variable categorica: 'host_identity_verified'

# %%
table8=freq_tbl(Micro_Retailer['host_identity_verified'])
table8
# Out:
#   host_identity_verified  frequency  percentage  cumulative_perc
# 0                      t       7514    0.908695         0.908695
# 1                      f        755    0.091305         1.000000

# %%
table8_8= table8.drop(['percentage', 'cumulative_perc'], axis=1)
table8_8
# Out:
#   host_identity_verified  frequency
# 0                      t       7514
# 1                      f        755

# %%
Filtro_index8= table8_8.set_index('host_identity_verified')
Filtro_index8
# Out:
#                         frequency
# host_identity_verified
# t                            7514
# f                             755

# %%
Filtro_index8["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 9 Análisis univariado de una variable categorica: 'property_type'

# %%
table9=freq_tbl(Micro_Retailer['property_type'])
table9
# Out:
#                          property_type  frequency  percentage  cumulative_perc
# 0                   Entire rental unit       4298    0.519773         0.519773
# 1          Private room in rental unit        732    0.088523         0.608296
# 2                         Entire condo        718    0.086830         0.695126
# 3                          Entire home        711    0.085984         0.781110
# 4                 Private room in home        491    0.059378         0.840489
# 5            Entire serviced apartment        234    0.028298         0.868787
# 6                        Room in hotel        231    0.027936         0.896723
# 7                   Entire guest suite        135    0.016326         0.913049
# 8                Private room in condo        122    0.014754         0.927803
# 9                     Entire townhouse        100    0.012093         0.939896
# 10                         Entire loft         66    0.007982         0.947878
# 11           Private room in townhouse         65    0.007861         0.955738
# 12              Room in boutique hotel         58    0.007014         0.962752
# 13   Private room in bed and breakfast         52    0.006289         0.969041
# 14                   Entire guesthouse         50    0.006047         0.975088
# 15                 Shared room in home         31    0.003749         0.978837
# 16            Private room in bungalow         23    0.002781         0.981618
# 17          Shared room in rental unit         22    0.002661         0.984279
# 18                Private room in loft         18    0.002177         0.986455
# 19                     Entire bungalow         17    0.002056         0.988511
# 20         Private room in guest suite         17    0.002056         0.990567
# 21                Entire vacation home         10    0.001209         0.991777
# 22          Room in serviced apartment          9    0.001088         0.992865
# 23           Room in bed and breakfast          9    0.001088         0.993953
# 24                           Tiny home          6    0.000726         0.994679
# 25                        Entire place          6    0.000726         0.995405
# 26          Private room in guesthouse          5    0.000605         0.996009
# 27              Private room in hostel          3    0.000363         0.996372
# 28                      Entire cottage          3    0.000363         0.996735
# 29               Shared room in hostel          3    0.000363         0.997098
# 30                                Boat          3    0.000363         0.997460
# 31             Private room in cottage          2    0.000242         0.997702
# 32           Private room in farm stay          2    0.000242         0.997944
# 33                  Room in aparthotel          2    0.000242         0.998186
# 34                        Entire villa          2    0.000242         0.998428
# 35     Private room in casa particular          2    0.000242         0.998670
# 36  Private room in serviced apartment          2    0.000242         0.998912
# 37                        Private room          1    0.000121         0.999033
# 38             Shared room in bungalow          1    0.000121         0.999153
# 39                     Casa particular          1    0.000121         0.999274
# 40               Private room in villa          1    0.000121         0.999395
# 41               Private room in minsu          1    0.000121         0.999516
# 42               Private room in tower          1    0.000121         0.999637
# 43                         Shared room          1    0.000121         0.999758
# 44           Shared room in guesthouse          1    0.000121         0.999879
# 45    Shared room in bed and breakfast          1    0.000121         1.000000

# %%
table9_9= table9.drop(['percentage', 'cumulative_perc'], axis=1)
table9_9
# Out:
#                          property_type  frequency
# 0                   Entire rental unit       4298
# 1          Private room in rental unit        732
# 2                         Entire condo        718
# 3                          Entire home        711
# 4                 Private room in home        491
# 5            Entire serviced apartment        234
# 6                        Room in hotel        231
# 7                   Entire guest suite        135
# 8                Private room in condo        122
# 9                     Entire townhouse        100
# 10                         Entire loft         66
# 11           Private room in townhouse         65
# 12              Room in boutique hotel         58
# 13   Private room in bed and breakfast         52
# 14                   Entire guesthouse         50
# 15                 Shared room in home         31
# 16            Private room in bungalow         23
# 17          Shared room in rental unit         22
# 18                Private room in loft         18
# 19                     Entire bungalow         17
# 20         Private room in guest suite         17
# 21                Entire vacation home         10
# 22          Room in serviced apartment          9
# 23           Room in bed and breakfast          9
# 24                           Tiny home          6
# 25                        Entire place          6
# 26          Private room in guesthouse          5
# 27              Private room in hostel          3
# 28                      Entire cottage          3
# 29               Shared room in hostel          3
# 30                                Boat          3
# 31             Private room in cottage          2
# 32           Private room in farm stay          2
# 33                  Room in aparthotel          2
# 34                        Entire villa          2
# 35     Private room in casa particular          2
# 36  Private room in serviced apartment          2
# 37                        Private room          1
# 38             Shared room in bungalow          1
# 39                     Casa particular          1
# 40               Private room in villa          1
# 41               Private room in minsu          1
# 42               Private room in tower          1
# 43                         Shared room          1
# 44           Shared room in guesthouse          1
# 45    Shared room in bed and breakfast          1

# %%
Filtro9=table9_9[table9_9['frequency']>49]
Filtro9
# Out:
#                         property_type  frequency
# 0                  Entire rental unit       4298
# 1         Private room in rental unit        732
# 2                        Entire condo        718
# 3                         Entire home        711
# 4                Private room in home        491
# 5           Entire serviced apartment        234
# 6                       Room in hotel        231
# 7                  Entire guest suite        135
# 8               Private room in condo        122
# 9                    Entire townhouse        100
# 10                        Entire loft         66
# 11          Private room in townhouse         65
# 12             Room in boutique hotel         58
# 13  Private room in bed and breakfast         52
# 14                  Entire guesthouse         50

# %%
Filtro_index9= Filtro9.set_index('property_type')
Filtro_index9
# Out:
#                                    frequency
# property_type
# Entire rental unit                      4298
# Private room in rental unit              732
# Entire condo                             718
# Entire home                              711
# Private room in home                     491
# Entire serviced apartment                234
# Room in hotel                            231
# Entire guest suite                       135
# Private room in condo                    122
# Entire townhouse                         100
# Entire loft                               66
# Private room in townhouse                 65
# Room in boutique hotel                    58
# Private room in bed and breakfast         52
# Entire guesthouse                         50

# %%
Filtro_index9.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Tipo de propiedad')
plt.xlabel('Propiedad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 10 Análisis univariado de una variable categorica: 'room_type'

# %%
table10=freq_tbl(Micro_Retailer['room_type'])
table10
# Out:
#          room_type  frequency  percentage  cumulative_perc
# 0  Entire home/apt       6360    0.769138         0.769138
# 1     Private room       1731    0.209336         0.978474
# 2       Hotel room        118    0.014270         0.992744
# 3      Shared room         60    0.007256         1.000000

# %%
table10_10= table10.drop(['percentage', 'cumulative_perc'], axis=1)
table10_10
# Out:
#          room_type  frequency
# 0  Entire home/apt       6360
# 1     Private room       1731
# 2       Hotel room        118
# 3      Shared room         60

# %%
Filtro_index10= table10_10.set_index('room_type')
Filtro_index10
# Out:
#                  frequency
# room_type
# Entire home/apt       6360
# Private room          1731
# Hotel room             118
# Shared room             60

# %%
Filtro_index10.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "grey")
plt.title('Tipo de habitación')
plt.xlabel('Habitación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 11 Análisis univariado de una variable categorica: 'bathrooms_text'

# %%
table11=freq_tbl(Micro_Retailer['bathrooms_text'])
table11
# Out:
#        bathrooms_text  frequency  percentage  cumulative_perc
# 0              1 bath       4404    0.532592         0.532592
# 1             2 baths       1469    0.177651         0.710243
# 2       1 shared bath        688    0.083202         0.793445
# 3      1 private bath        395    0.047769         0.841214
# 4           1.5 baths        242    0.029266         0.870480
# 5             3 baths        213    0.025759         0.896239
# 6           2.5 baths        208    0.025154         0.921393
# 7      2 shared baths        191    0.023098         0.944491
# 8           3.5 baths        108    0.013061         0.957552
# 9    1.5 shared baths         96    0.011610         0.969162
# 10            4 baths         82    0.009917         0.979078
# 11   2.5 shared baths         21    0.002540         0.981618
# 12     3 shared baths         21    0.002540         0.984158
# 13          4.5 baths         20    0.002419         0.986576
# 14            0 baths         19    0.002298         0.988874
# 15            6 baths         18    0.002177         0.991051
# 16            5 baths         11    0.001330         0.992381
# 17             1 baño         11    0.001330         0.993711
# 18          Half-bath         10    0.001209         0.994921
# 19     0 shared baths          7    0.000847         0.995767
# 20          5.5 baths          4    0.000484         0.996251
# 21            8 baths          4    0.000484         0.996735
# 22          6.5 baths          4    0.000484         0.997219
# 23            9 baths          3    0.000363         0.997581
# 24           10 baths          3    0.000363         0.997944
# 25    11 shared baths          3    0.000363         0.998307
# 26            7 baths          3    0.000363         0.998670
# 27  Private half-bath          2    0.000242         0.998912
# 28          7.5 baths          2    0.000242         0.999153
# 29           12 baths          2    0.000242         0.999395
# 30   Shared half-bath          1    0.000121         0.999516
# 31  11.5 shared baths          1    0.000121         0.999637
# 32          9.5 baths          1    0.000121         0.999758
# 33          8.5 baths          1    0.000121         0.999879
# 34     4 shared baths          1    0.000121         1.000000

# %%
table11_11= table11.drop(['percentage', 'cumulative_perc'], axis=1)
table11_11
# Out:
#        bathrooms_text  frequency
# 0              1 bath       4404
# 1             2 baths       1469
# 2       1 shared bath        688
# 3      1 private bath        395
# 4           1.5 baths        242
# 5             3 baths        213
# 6           2.5 baths        208
# 7      2 shared baths        191
# 8           3.5 baths        108
# 9    1.5 shared baths         96
# 10            4 baths         82
# 11   2.5 shared baths         21
# 12     3 shared baths         21
# 13          4.5 baths         20
# 14            0 baths         19
# 15            6 baths         18
# 16            5 baths         11
# 17             1 baño         11
# 18          Half-bath         10
# 19     0 shared baths          7
# 20          5.5 baths          4
# 21            8 baths          4
# 22          6.5 baths          4
# 23            9 baths          3
# 24           10 baths          3
# 25    11 shared baths          3
# 26            7 baths          3
# 27  Private half-bath          2
# 28          7.5 baths          2
# 29           12 baths          2
# 30   Shared half-bath          1
# 31  11.5 shared baths          1
# 32          9.5 baths          1
# 33          8.5 baths          1
# 34     4 shared baths          1

# %%
Filtro11=table11_11[table11_11['frequency']>22]
Filtro11
# Out:
#       bathrooms_text  frequency
# 0             1 bath       4404
# 1            2 baths       1469
# 2      1 shared bath        688
# 3     1 private bath        395
# 4          1.5 baths        242
# 5            3 baths        213
# 6          2.5 baths        208
# 7     2 shared baths        191
# 8          3.5 baths        108
# 9   1.5 shared baths         96
# 10           4 baths         82

# %%
Filtro_index11= Filtro11.set_index('bathrooms_text')
Filtro_index11
# Out:
#                   frequency
# bathrooms_text
# 1 bath                 4404
# 2 baths                1469
# 1 shared bath           688
# 1 private bath          395
# 1.5 baths               242
# 3 baths                 213
# 2.5 baths               208
# 2 shared baths          191
# 3.5 baths               108
# 1.5 shared baths         96
# 4 baths                  82

# %%
Filtro_index11.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "brown")
plt.title('Descripción de baños')
plt.xlabel('Baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 12 Análisis univariado de una variable categorica: 'has_availability'

# %%
table12=freq_tbl(Micro_Retailer['has_availability'])
table12
# Out:
#   has_availability  frequency  percentage  cumulative_perc
# 0                t       8224    0.994558         0.994558
# 1                f         45    0.005442         1.000000

# %%
table12_12= table12.drop(['percentage', 'cumulative_perc'], axis=1)
table12_12
# Out:
#   has_availability  frequency
# 0                t       8224
# 1                f         45

# %%
Filtro_index12= table12_12.set_index('has_availability')
Filtro_index12
# Out:
#                   frequency
# has_availability
# t                      8224
# f                        45

# %%
Filtro_index12["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 13 Análisis univariado de una variable categorica: 'first_review'

# %%
table13=freq_tbl(Micro_Retailer['first_review'])
table13
# Out:
#      first_review  frequency  percentage  cumulative_perc
# 0       Sin fecha       1590    0.192284         0.192284
# 1      11/08/2024         26    0.003144         0.195429
# 2      17/03/2024         25    0.003023         0.198452
# 3      07/05/2023         25    0.003023         0.201475
# 4      02/09/2024         24    0.002902         0.204378
# ...           ...        ...         ...              ...
# 2310   12/09/2024          1    0.000121         0.999516
# 2311   18/09/2011          1    0.000121         0.999637
# 2312   05/06/2015          1    0.000121         0.999758
# 2313   27/08/2024          1    0.000121         0.999879
# 2314   29/06/2015          1    0.000121         1.000000
#
# [2315 rows x 4 columns]

# %%
table13_13= table13.drop(['percentage', 'cumulative_perc'], axis=1)
table13_13
# Out:
#      first_review  frequency
# 0       Sin fecha       1590
# 1      11/08/2024         26
# 2      17/03/2024         25
# 3      07/05/2023         25
# 4      02/09/2024         24
# ...           ...        ...
# 2310   12/09/2024          1
# 2311   18/09/2011          1
# 2312   05/06/2015          1
# 2313   27/08/2024          1
# 2314   29/06/2015          1
#
# [2315 rows x 2 columns]

# %%
Filtro13=table13_13[table13_13['frequency']>20]
Filtro13
# Out:
#   first_review  frequency
# 0    Sin fecha       1590
# 1   11/08/2024         26
# 2   17/03/2024         25
# 3   07/05/2023         25
# 4   02/09/2024         24
# 5   27/05/2024         24
# 6   02/06/2024         23
# 7   04/06/2023         21
# 8   04/09/2023         21

# %%
Filtro_index13= Filtro13.set_index('first_review')
Filtro_index13
# Out:
#               frequency
# first_review
# Sin fecha          1590
# 11/08/2024           26
# 17/03/2024           25
# 07/05/2023           25
# 02/09/2024           24
# 27/05/2024           24
# 02/06/2024           23
# 04/06/2023           21
# 04/09/2023           21

# %%
Filtro_index13.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "gold")
plt.title('Fecha de primera reseña')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 14 Análisis univariado de una variable categorica: 'last_review'

# %%
table14=freq_tbl(Micro_Retailer['last_review'])
table14
# Out:
#     last_review  frequency  percentage  cumulative_perc
# 0     Sin fecha       1590    0.192284         0.192284
# 1    02/09/2024        672    0.081267         0.273552
# 2    01/09/2024        349    0.042206         0.315758
# 3    08/09/2024        312    0.037731         0.353489
# 4    15/09/2024        257    0.031080         0.384569
# ..          ...        ...         ...              ...
# 744  01/03/2020          1    0.000121         0.999516
# 745  16/09/2022          1    0.000121         0.999637
# 746  21/10/2023          1    0.000121         0.999758
# 747  08/03/2024          1    0.000121         0.999879
# 748  06/09/2023          1    0.000121         1.000000
#
# [749 rows x 4 columns]

# %%
table14_14= table14.drop(['percentage', 'cumulative_perc'], axis=1)
table14_14
# Out:
#     last_review  frequency
# 0     Sin fecha       1590
# 1    02/09/2024        672
# 2    01/09/2024        349
# 3    08/09/2024        312
# 4    15/09/2024        257
# ..          ...        ...
# 744  01/03/2020          1
# 745  16/09/2022          1
# 746  21/10/2023          1
# 747  08/03/2024          1
# 748  06/09/2023          1
#
# [749 rows x 2 columns]

# %%
Filtro14=table14_14[table14_14['frequency']>100]
Filtro14
# Out:
#    last_review  frequency
# 0    Sin fecha       1590
# 1   02/09/2024        672
# 2   01/09/2024        349
# 3   08/09/2024        312
# 4   15/09/2024        257
# 5   09/09/2024        250
# 6   25/08/2024        181
# 7   14/09/2024        164
# 8   13/09/2024        158
# 9   03/09/2024        147
# 10  12/09/2024        144
# 11  10/09/2024        131
# 12  18/08/2024        126
# 13  23/08/2024        125
# 14  31/08/2024        125
# 15  11/09/2024        116
# 16  26/08/2024        115
# 17  16/09/2024        109
# 18  30/08/2024        108

# %%
Filtro_index14= Filtro14.set_index('last_review')
Filtro_index14
# Out:
#              frequency
# last_review
# Sin fecha         1590
# 02/09/2024         672
# 01/09/2024         349
# 08/09/2024         312
# 15/09/2024         257
# 09/09/2024         250
# 25/08/2024         181
# 14/09/2024         164
# 13/09/2024         158
# 03/09/2024         147
# 12/09/2024         144
# 10/09/2024         131
# 18/08/2024         126
# 23/08/2024         125
# 31/08/2024         125
# 11/09/2024         116
# 26/08/2024         115
# 16/09/2024         109
# 30/08/2024         108

# %%
Filtro_index14.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Fecha de ultima reseña')
plt.xlabel('Fecha')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 15 Análisis univariado de una variable categorica: 'license'

# %%
table15=freq_tbl(Micro_Retailer['license'])
table15
# Out:
#                         license  frequency  percentage  cumulative_perc
# 0                  Sin licencia       1692    0.204620         0.204620
# 1     City registration pending        211    0.025517         0.230137
# 2                       2792126        135    0.016326         0.246463
# 3              32+ Days Listing        110    0.013303         0.259765
# 4                       2863615         56    0.006772         0.266538
# ...                         ...        ...         ...              ...
# 4201                    2209984          1    0.000121         0.999516
# 4202               R24000114046          1    0.000121         0.999637
# 4203               R17000015609          1    0.000121         0.999758
# 4204               R24000118819          1    0.000121         0.999879
# 4205               R23000108435          1    0.000121         1.000000
#
# [4206 rows x 4 columns]

# %%
table15_15= table15.drop(['percentage', 'cumulative_perc'], axis=1)
table15_15
# Out:
#                         license  frequency
# 0                  Sin licencia       1692
# 1     City registration pending        211
# 2                       2792126        135
# 3              32+ Days Listing        110
# 4                       2863615         56
# ...                         ...        ...
# 4201                    2209984          1
# 4202               R24000114046          1
# 4203               R17000015609          1
# 4204               R24000118819          1
# 4205               R23000108435          1
#
# [4206 rows x 2 columns]

# %%
Filtro15=table15_15[table15_15['frequency']>15]
Filtro15
# Out:
#                       license  frequency
# 0                Sin licencia       1692
# 1   City registration pending        211
# 2                     2792126        135
# 3            32+ Days Listing        110
# 4                     2863615         56
# 5             32+days Listing         45
# 6                     2205418         29
# 7                     2780536         22
# 8                     2834965         22
# 9                R19000046222         18
# 10               R23000105602         17
# 11                    2506121         17
# 12               R17000014173         16

# %%
Filtro_index15= Filtro15.set_index('license')
Filtro_index15
# Out:
#                            frequency
# license
# Sin licencia                    1692
# City registration pending        211
# 2792126                          135
# 32+ Days Listing                 110
# 2863615                           56
# 32+days Listing                   45
# 2205418                           29
# 2780536                           22
# 2834965                           22
# R19000046222                      18
# R23000105602                      17
# 2506121                           17
# R17000014173                      16

# %%
Filtro_index15.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Licencia')
plt.xlabel('Licencia')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 16 Análisis univariado de una variable categorica: 'instant_bookable'

# %%
table16=freq_tbl(Micro_Retailer['instant_bookable'])
table16
# Out:
#   instant_bookable  frequency  percentage  cumulative_perc
# 0                f       5218    0.631032         0.631032
# 1                t       3051    0.368968         1.000000

# %%
table16_16= table16.drop(['percentage', 'cumulative_perc'], axis=1)
table16_16
# Out:
#   instant_bookable  frequency
# 0                f       5218
# 1                t       3051

# %%
Filtro_index16= table16_16.set_index('instant_bookable')
Filtro_index16
# Out:
#                   frequency
# instant_bookable
# f                      5218
# t                      3051

# %%
Filtro_index16["frequency"].plot(kind='pie', figsize=(10,5), shadow= True, autopct= "%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# 17 Análisis univariado de una variable categorica: 'host_id'

# %%
Micro_Retailer['host_id'] = Micro_Retailer['host_id'].astype(str)

# %%
table17=freq_tbl(Micro_Retailer['host_id'])
table17
# Out:
#         host_id  frequency  percentage  cumulative_perc
# 0     107434423        516    0.062402         0.062402
# 1     446820235        118    0.014270         0.076672
# 2     248760412         83    0.010037         0.086709
# 3     395498979         67    0.008103         0.094812
# 4     501999278         64    0.007740         0.102552
# ...         ...        ...         ...              ...
# 3547  596549251          1    0.000121         0.999516
# 3548   87810623          1    0.000121         0.999637
# 3549   14476089          1    0.000121         0.999758
# 3550    6603668          1    0.000121         0.999879
# 3551   12303404          1    0.000121         1.000000
#
# [3552 rows x 4 columns]

# %%
table17_17= table17.drop(['percentage', 'cumulative_perc'], axis=1)
table17_17
# Out:
#         host_id  frequency
# 0     107434423        516
# 1     446820235        118
# 2     248760412         83
# 3     395498979         67
# 4     501999278         64
# ...         ...        ...
# 3547  596549251          1
# 3548   87810623          1
# 3549   14476089          1
# 3550    6603668          1
# 3551   12303404          1
#
# [3552 rows x 2 columns]

# %%
Filtro17=table17_17[table17_17['frequency']>20]
Filtro17
# Out:
#       host_id  frequency
# 0   107434423        516
# 1   446820235        118
# 2   248760412         83
# 3   395498979         67
# 4   501999278         64
# 5   177188450         59
# 6   391945218         58
# 7   457438194         51
# 8   501999514         44
# 9   435105119         43
# 10  243035563         40
# 11  588459029         37
# 12    3965428         35
# 13  396270947         33
# 14   98193524         33
# 15  501371725         29
# 16  121719854         29
# 17  100782278         29
# 18  367411016         29
# 19  565344683         29
# 20  235678953         28
# 21  370154553         28
# 22  263502162         28
# 23  377884322         27
# 24  170551048         26
# 25   96730613         26
# 26  545236821         26
# 27  464407683         25
# 28  126179580         24
# 29  188365982         24
# 30     683529         23
# 31   35342456         23
# 32   53964832         22
# 33  497660633         22
# 34  395806758         22
# 35   43933909         22
# 36  169297663         21
# 37    5228189         21

# %%
Filtro_index17= Filtro17.set_index('host_id')
Filtro_index17
# Out:
#            frequency
# host_id
# 107434423        516
# 446820235        118
# 248760412         83
# 395498979         67
# 501999278         64
# 177188450         59
# 391945218         58
# 457438194         51
# 501999514         44
# 435105119         43
# 243035563         40
# 588459029         37
# 3965428           35
# 396270947         33
# 98193524          33
# 501371725         29
# 121719854         29
# 100782278         29
# 367411016         29
# 565344683         29
# 235678953         28
# 370154553         28
# 263502162         28
# 377884322         27
# 170551048         26
# 96730613          26
# 545236821         26
# 464407683         25
# 126179580         24
# 188365982         24
# 683529            23
# 35342456          23
# 53964832          22
# 497660633         22
# 395806758         22
# 43933909          22
# 169297663         21
# 5228189           21

# %%
Filtro_index17.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Número de identificación')
plt.xlabel('ID')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 18 Análisis univariado de una variable categorica: 'maximum_nights'

# %%
Micro_Retailer['maximum_nights'] = Micro_Retailer['maximum_nights'].astype(str)

# %%
table18=freq_tbl(Micro_Retailer['maximum_nights'])
table18
# Out:
#     maximum_nights  frequency  percentage  cumulative_perc
# 0              365       3162    0.382392         0.382392
# 1             1125       2297    0.277784         0.660177
# 2               90        461    0.055750         0.715927
# 3               30        322    0.038941         0.754868
# 4               28        309    0.037368         0.792236
# ..             ...        ...         ...              ...
# 137            357          1    0.000121         0.999516
# 138            965          1    0.000121         0.999637
# 139            242          1    0.000121         0.999758
# 140             43          1    0.000121         0.999879
# 141            340          1    0.000121         1.000000
#
# [142 rows x 4 columns]

# %%
table18_18= table18.drop(['percentage', 'cumulative_perc'], axis=1)
table18_18
# Out:
#     maximum_nights  frequency
# 0              365       3162
# 1             1125       2297
# 2               90        461
# 3               30        322
# 4               28        309
# ..             ...        ...
# 137            357          1
# 138            965          1
# 139            242          1
# 140             43          1
# 141            340          1
#
# [142 rows x 2 columns]

# %%
Filtro18=table18_18[table18_18['frequency']>44]
Filtro18
# Out:
#    maximum_nights  frequency
# 0             365       3162
# 1            1125       2297
# 2              90        461
# 3              30        322
# 4              28        309
# 5             180        149
# 6             730        140
# 7              60        140
# 8              14        103
# 9             120         98
# 10             29         87
# 11              7         62
# 12             21         57

# %%
Filtro_index18= Filtro18.set_index('maximum_nights')
Filtro_index18
# Out:
#                 frequency
# maximum_nights
# 365                  3162
# 1125                 2297
# 90                    461
# 30                    322
# 28                    309
# 180                   149
# 730                   140
# 60                    140
# 14                    103
# 120                    98
# 29                     87
# 7                      62
# 21                     57

# %%
Filtro_index18.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Número maximo de noches')
plt.xlabel('Noches')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 19 Análisis univariado de una variable categorica: ' availability_365'

# %%
Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].astype(str)

# %%
table19=freq_tbl(Micro_Retailer['availability_365'])
table19
# Out:
#     availability_365  frequency  percentage  cumulative_perc
# 0                365        431    0.052122         0.052122
# 1                  0        232    0.028057         0.080179
# 2                363        166    0.020075         0.100254
# 3                364         85    0.010279         0.110533
# 4                340         73    0.008828         0.119361
# ..               ...        ...         ...              ...
# 361                4          4    0.000484         0.998670
# 362              191          3    0.000363         0.999033
# 363               11          3    0.000363         0.999395
# 364              202          3    0.000363         0.999758
# 365              208          2    0.000242         1.000000
#
# [366 rows x 4 columns]

# %%
table19_19= table19.drop(['percentage', 'cumulative_perc'], axis=1)
table19_19
# Out:
#     availability_365  frequency
# 0                365        431
# 1                  0        232
# 2                363        166
# 3                364         85
# 4                340         73
# ..               ...        ...
# 361                4          4
# 362              191          3
# 363               11          3
# 364              202          3
# 365              208          2
#
# [366 rows x 2 columns]

# %%
Filtro19=table19_19[table19_19['frequency']>50]
Filtro19
# Out:
#    availability_365  frequency
# 0               365        431
# 1                 0        232
# 2               363        166
# 3               364         85
# 4               340         73
# 5               180         68
# 6               269         65
# 7               347         61
# 8               339         59
# 9                89         59
# 10              337         58
# 11              352         57
# 12              345         56
# 13              343         56
# 14              270         56
# 15              334         55
# 16              333         55
# 17              348         54
# 18              341         52
# 19              338         51

# %%
Filtro_index19= Filtro19.set_index('availability_365')
Filtro_index19
# Out:
#                   frequency
# availability_365
# 365                     431
# 0                       232
# 363                     166
# 364                      85
# 340                      73
# 180                      68
# 269                      65
# 347                      61
# 339                      59
# 89                       59
# 337                      58
# 352                      57
# 345                      56
# 343                      56
# 270                      56
# 334                      55
# 333                      55
# 348                      54
# 341                      52
# 338                      51

# %%
Filtro_index19.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "blue")
plt.title('Noches disponibles en 365 días')
plt.xlabel('Noches')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# 20 Análisis univariado de una variable categorica: 'availability_30'

# %%
Micro_Retailer['availability_30'] = Micro_Retailer['availability_30'].astype(str)

# %%
table20=freq_tbl(Micro_Retailer['availability_30'])
table20
# Out:
#    availability_30  frequency  percentage  cumulative_perc
# 0                0       1522    0.184061         0.184061
# 1               30        710    0.085863         0.269924
# 2               12        304    0.036764         0.306688
# 3               14        298    0.036038         0.342726
# 4               11        286    0.034587         0.377313
# 5               16        285    0.034466         0.411779
# 6               13        280    0.033861         0.445640
# 7                9        262    0.031685         0.477325
# 8               28        245    0.029629         0.506954
# 9               15        239    0.028903         0.535857
# 10              17        237    0.028661         0.564518
# 11              10        237    0.028661         0.593179
# 12              18        232    0.028057         0.621236
# 13               8        232    0.028057         0.649293
# 14               7        215    0.026001         0.675293
# 15              19        211    0.025517         0.700810
# 16               6        209    0.025275         0.726085
# 17               5        204    0.024670         0.750756
# 18              29        201    0.024308         0.775063
# 19               4        188    0.022736         0.797799
# 20               2        186    0.022494         0.820293
# 21              20        179    0.021647         0.841940
# 22               3        170    0.020559         0.862498
# 23               1        168    0.020317         0.882815
# 24              23        167    0.020196         0.903011
# 25              21        166    0.020075         0.923086
# 26              22        156    0.018866         0.941952
# 27              24        140    0.016931         0.958883
# 28              27        119    0.014391         0.973274
# 29              26        113    0.013665         0.986939
# 30              25        108    0.013061         1.000000

# %%
table20_20= table20.drop(['percentage', 'cumulative_perc'], axis=1)
table20_20
# Out:
#    availability_30  frequency
# 0                0       1522
# 1               30        710
# 2               12        304
# 3               14        298
# 4               11        286
# 5               16        285
# 6               13        280
# 7                9        262
# 8               28        245
# 9               15        239
# 10              17        237
# 11              10        237
# 12              18        232
# 13               8        232
# 14               7        215
# 15              19        211
# 16               6        209
# 17               5        204
# 18              29        201
# 19               4        188
# 20               2        186
# 21              20        179
# 22               3        170
# 23               1        168
# 24              23        167
# 25              21        166
# 26              22        156
# 27              24        140
# 28              27        119
# 29              26        113
# 30              25        108

# %%
Filtro20=table20_20[table20_20['frequency']>9]
Filtro20
# Out:
#    availability_30  frequency
# 0                0       1522
# 1               30        710
# 2               12        304
# 3               14        298
# 4               11        286
# 5               16        285
# 6               13        280
# 7                9        262
# 8               28        245
# 9               15        239
# 10              17        237
# 11              10        237
# 12              18        232
# 13               8        232
# 14               7        215
# 15              19        211
# 16               6        209
# 17               5        204
# 18              29        201
# 19               4        188
# 20               2        186
# 21              20        179
# 22               3        170
# 23               1        168
# 24              23        167
# 25              21        166
# 26              22        156
# 27              24        140
# 28              27        119
# 29              26        113
# 30              25        108

# %%
Filtro_index20= Filtro20.set_index('availability_30')
Filtro_index20
# Out:
#                  frequency
# availability_30
# 0                     1522
# 30                     710
# 12                     304
# 14                     298
# 11                     286
# 16                     285
# 13                     280
# 9                      262
# 28                     245
# 15                     239
# 17                     237
# 10                     237
# 18                     232
# 8                      232
# 7                      215
# 19                     211
# 6                      209
# 5                      204
# 29                     201
# 4                      188
# 2                      186
# 20                     179
# 3                      170
# 1                      168
# 23                     167
# 21                     166
# 22                     156
# 24                     140
# 27                     119
# 26                     113
# 25                     108

# %%
Filtro_index20.plot(kind= 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Noches disponibles en 30 días')
plt.xlabel('Noches')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# CATEGORIZACIÓN DE VARIABLES

# %% [markdown]
# Categorización de variable 'host_acceptance_rate'

# %%
Micro_Retailer['host_acceptance_rate']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: host_acceptance_rate
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['host_acceptance_rate'].max()
Min=Micro_Retailer['host_acceptance_rate'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(75.0), np.float64(100.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(25.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
i=R/ni
i
# Out:
# np.float64(1.7849564527191826)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([ 75.   ,  78.125,  81.25 ,  84.375,  87.5  ,  90.625,  93.75 ,
#         96.875, 100.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['host_acceptance_rate']=pd.cut(x= Micro_Retailer['host_acceptance_rate'], bins=intervalos, labels=categorias)
Micro_Retailer['host_acceptance_rate']
# Out:
# 0       Categoria5
# 1       Categoria8
# 2       Categoria7
# 3              NaN
# 4       Categoria5
#            ...
# 8264    Categoria8
# 8265    Categoria8
# 8266    Categoria4
# 8267    Categoria8
# 8268    Categoria8
# Name: host_acceptance_rate, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
print(Micro_Retailer['host_acceptance_rate'].unique())
# Out:
# ['Categoria5', 'Categoria8', 'Categoria7', NaN, 'Categoria6', 'Categoria1', 'Categoria2', 'Categoria4', 'Categoria3']
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['host_acceptance_rate'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Tasa de aceptación del anfitrión')
plt.xlabel('Aceptación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'host_total_listings_count'

# %%
Micro_Retailer['host_total_listings_count']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['host_total_listings_count'].max()
Min=Micro_Retailer['host_total_listings_count'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(1.0), np.float64(69.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(68.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([ 1. ,  9.5, 18. , 26.5, 35. , 43.5, 52. , 60.5, 69. ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['host_total_listings_count']=pd.cut(x= Micro_Retailer['host_total_listings_count'], bins=intervalos, labels=categorias)
Micro_Retailer['host_total_listings_count']
# Out:
# 0              NaN
# 1       Categoria1
# 2       Categoria2
# 3              NaN
# 4       Categoria1
#            ...
# 8264    Categoria1
# 8265    Categoria2
# 8266    Categoria1
# 8267    Categoria1
# 8268    Categoria2
# Name: host_total_listings_count, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['host_total_listings_count'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Total de propiedades del anfitrión')
plt.xlabel('Propiedades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'accommodates'

# %%
Micro_Retailer['accommodates']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['accommodates'].max()
Min=Micro_Retailer['accommodates'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(1.0), np.float64(12.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(11.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([ 1.   ,  2.375,  3.75 ,  5.125,  6.5  ,  7.875,  9.25 , 10.625,
#        12.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['accommodates']=pd.cut(x= Micro_Retailer['accommodates'], bins=intervalos, labels=categorias)
Micro_Retailer['accommodates']
# Out:
# 0              NaN
# 1       Categoria1
# 2       Categoria3
# 3       Categoria2
# 4       Categoria4
#            ...
# 8264    Categoria3
# 8265    Categoria6
# 8266    Categoria3
# 8267    Categoria3
# 8268    Categoria4
# Name: accommodates, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['accommodates'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Capacidad maxima')
plt.xlabel('Capacidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'bathrooms_text'

# %%
Micro_Retailer['bathrooms_text'] = Micro_Retailer['bathrooms_text'].str.extract('(\d+)')
# Convertir a float
Micro_Retailer['bathrooms_text'] = Micro_Retailer['bathrooms_text'].astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\yack_\AppData\Local\Temp\ipykernel_1688\2327146491.py:1: SyntaxWarning: invalid escape sequence '\d'
#   Micro_Retailer['bathrooms_text'] = Micro_Retailer['bathrooms_text'].str.extract('(\d+)')

# %%
Micro_Retailer['bathrooms_text']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 8256 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['bathrooms_text'].max()
Min=Micro_Retailer['bathrooms_text'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(12.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(12.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 6)
intervalos
# Out:
# array([ 0. ,  2.4,  4.8,  7.2,  9.6, 12. ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5"]

# %%
Micro_Retailer['bathrooms_text']=pd.cut(x= Micro_Retailer['bathrooms_text'], bins=intervalos, labels=categorias)
Micro_Retailer['bathrooms_text']
# Out:
# 0       Categoria1
# 1       Categoria1
# 2       Categoria1
# 3       Categoria1
# 4       Categoria1
#            ...
# 8264    Categoria1
# 8265    Categoria1
# 8266    Categoria1
# 8267    Categoria1
# 8268    Categoria1
# Name: bathrooms_text, Length: 8269, dtype: category
# Categories (5, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5']

# %%
Micro_Retailer['bathrooms_text'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "blue")
plt.title('Número de baños')
plt.xlabel('Baños')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'beds'

# %%
Micro_Retailer['beds']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['beds'].max()
Min=Micro_Retailer['beds'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(6.0)]

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([0.  , 0.75, 1.5 , 2.25, 3.  , 3.75, 4.5 , 5.25, 6.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['beds']=pd.cut(x= Micro_Retailer['beds'], bins=intervalos, labels=categorias)
Micro_Retailer['beds']
# Out:
# 0       Categoria2
# 1       Categoria2
# 2       Categoria3
# 3       Categoria2
# 4       Categoria4
#            ...
# 8264    Categoria3
# 8265    Categoria6
# 8266    Categoria4
# 8267    Categoria3
# 8268    Categoria4
# Name: beds, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['beds'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Número de camas')
plt.xlabel('Camas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'price'

# %%
Micro_Retailer['price']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['price'].max()
Min=Micro_Retailer['price'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(18.0), np.float64(423.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(405.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([ 18.   ,  68.625, 119.25 , 169.875, 220.5  , 271.125, 321.75 ,
#        372.375, 423.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['price']=pd.cut(x= Micro_Retailer['price'], bins=intervalos, labels=categorias)
Micro_Retailer['price']
# Out:
# 0       Categoria3
# 1       Categoria2
# 2       Categoria4
# 3       Categoria7
# 4       Categoria4
#            ...
# 8264    Categoria1
# 8265    Categoria3
# 8266    Categoria4
# 8267    Categoria2
# 8268    Categoria2
# Name: price, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['price'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "gold")
plt.title('Precio')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'availability_365'

# %%
Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].str.extract('(\d+)')

# Convertir a float
Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\yack_\AppData\Local\Temp\ipykernel_1688\176713607.py:1: SyntaxWarning: invalid escape sequence '\d'
#   Micro_Retailer['availability_365'] = Micro_Retailer['availability_365'].str.extract('(\d+)')

# %%
Micro_Retailer['availability_365']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['availability_365'].max()
Min=Micro_Retailer['availability_365'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(365.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(365.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([  0.   ,  45.625,  91.25 , 136.875, 182.5  , 228.125, 273.75 ,
#        319.375, 365.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['availability_365']=pd.cut(x= Micro_Retailer['availability_365'], bins=intervalos, labels=categorias)
Micro_Retailer['availability_365']
# Out:
# 0       Categoria8
# 1       Categoria7
# 2       Categoria5
# 3       Categoria4
# 4       Categoria1
#            ...
# 8264    Categoria8
# 8265    Categoria1
# 8266    Categoria8
# 8267    Categoria2
# 8268    Categoria8
# Name: availability_365, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['availability_365'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Disponibilidad en 365 días')
plt.xlabel('Disponibilidad')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'number_of_reviews'

# %%
Micro_Retailer['number_of_reviews']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['number_of_reviews'].max()
Min=Micro_Retailer['number_of_reviews'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.0), np.float64(166.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(166.0)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([  0.  ,  20.75,  41.5 ,  62.25,  83.  , 103.75, 124.5 , 145.25,
#        166.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['number_of_reviews']=pd.cut(x= Micro_Retailer['number_of_reviews'], bins=intervalos, labels=categorias)
Micro_Retailer['number_of_reviews']
# Out:
# 0       Categoria2
# 1       Categoria2
# 2       Categoria6
# 3       Categoria1
# 4       Categoria2
#            ...
# 8264           NaN
# 8265           NaN
# 8266           NaN
# 8267           NaN
# 8268           NaN
# Name: number_of_reviews, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['number_of_reviews'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "pink")
plt.title('Reseñas')
plt.xlabel('Número de reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_location'

# %%
Micro_Retailer['review_scores_location']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: review_scores_location
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['review_scores_location'].max()
Min=Micro_Retailer['review_scores_location'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.45), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.5499999999999998)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.45   , 4.51875, 4.5875 , 4.65625, 4.725  , 4.79375, 4.8625 ,
#        4.93125, 5.     ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_location']=pd.cut(x= Micro_Retailer['review_scores_location'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_location']
# Out:
# 0       Categoria8
# 1       Categoria7
# 2       Categoria8
# 3       Categoria8
# 4       Categoria7
#            ...
# 8264    Categoria5
# 8265    Categoria5
# 8266    Categoria5
# 8267    Categoria5
# 8268    Categoria5
# Name: review_scores_location, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_location'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Ubicación')
plt.xlabel('Valor de ubicación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'reviews_per_month'

# %%
Micro_Retailer['reviews_per_month']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['reviews_per_month'].max()
Min=Micro_Retailer['reviews_per_month'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(0.01), np.float64(5.17)]

# %%
R=Max-Min
R
# Out:
# np.float64(5.16)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([0.01 , 0.655, 1.3  , 1.945, 2.59 , 3.235, 3.88 , 4.525, 5.17 ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['reviews_per_month']=pd.cut(x= Micro_Retailer['reviews_per_month'], bins=intervalos, labels=categorias)
Micro_Retailer['reviews_per_month']
# Out:
# 0       Categoria4
# 1       Categoria5
# 2       Categoria2
# 3       Categoria1
# 4       Categoria3
#            ...
# 8264    Categoria4
# 8265    Categoria4
# 8266    Categoria4
# 8267    Categoria4
# 8268    Categoria4
# Name: reviews_per_month, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['reviews_per_month'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "black")
plt.title('Reseñas por mes')
plt.xlabel('Reseñas')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_communication'

# %%
Micro_Retailer['review_scores_communication']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: review_scores_communication
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['review_scores_communication'].max()
Min=Micro_Retailer['review_scores_communication'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.65), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.34999999999999964)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.65   , 4.69375, 4.7375 , 4.78125, 4.825  , 4.86875, 4.9125 ,
#        4.95625, 5.     ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_communication']=pd.cut(x= Micro_Retailer['review_scores_communication'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_communication']
# Out:
# 0       Categoria8
# 1       Categoria6
# 2       Categoria6
# 3       Categoria8
# 4       Categoria5
#            ...
# 8264    Categoria5
# 8265    Categoria5
# 8266    Categoria5
# 8267    Categoria5
# 8268    Categoria5
# Name: review_scores_communication, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_communication'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "green")
plt.title('Valoración de comunicación')
plt.xlabel('Valoración')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_checkin'

# %%
Micro_Retailer['review_scores_checkin']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: review_scores_checkin
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['review_scores_checkin'].max()
Min=Micro_Retailer['review_scores_checkin'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.65), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.34999999999999964)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.65   , 4.69375, 4.7375 , 4.78125, 4.825  , 4.86875, 4.9125 ,
#        4.95625, 5.     ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_checkin']=pd.cut(x= Micro_Retailer['review_scores_checkin'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_checkin']
# Out:
# 0       Categoria8
# 1       Categoria6
# 2       Categoria5
# 3       Categoria8
# 4       Categoria7
#            ...
# 8264    Categoria5
# 8265    Categoria5
# 8266    Categoria5
# 8267    Categoria5
# 8268    Categoria5
# Name: review_scores_checkin, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_checkin'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "gold")
plt.title('Entrada')
plt.xlabel('Valoración de entrada')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_cleanliness'

# %%
Micro_Retailer['review_scores_cleanliness']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: review_scores_cleanliness
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['review_scores_cleanliness'].max()
Min=Micro_Retailer['review_scores_cleanliness'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.44), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.5599999999999996)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.44, 4.51, 4.58, 4.65, 4.72, 4.79, 4.86, 4.93, 5.  ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_cleanliness']=pd.cut(x= Micro_Retailer['review_scores_cleanliness'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_cleanliness']
# Out:
# 0       Categoria8
# 1       Categoria2
# 2       Categoria6
# 3       Categoria8
# 4       Categoria5
#            ...
# 8264    Categoria5
# 8265    Categoria5
# 8266    Categoria5
# 8267    Categoria5
# 8268    Categoria5
# Name: review_scores_cleanliness, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_cleanliness'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "orange")
plt.title('Limpieza')
plt.xlabel('Valoración de limpieza')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Categorización de variable 'review_scores_accuracy'

# %%
Micro_Retailer['review_scores_accuracy']. info()
n=8269
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8269 entries, 0 to 8268
# Series name: review_scores_accuracy
# Non-Null Count  Dtype
# --------------  -----
# 8269 non-null   float64
# dtypes: float64(1)
# memory usage: 64.7 KB

# %%
Max=Micro_Retailer['review_scores_accuracy'].max()
Min=Micro_Retailer['review_scores_accuracy'].min()
Limites=[Min, Max]
Limites
# Out:
# [np.float64(4.56), np.float64(5.0)]

# %%
R=Max-Min
R
# Out:
# np.float64(0.4400000000000004)

# %%
ni= 1+3.32*np.log10(n)
ni
# Out:
# np.float64(14.005943933206483)

# %%
intervalos=np.linspace(Min, Max, 9)
intervalos
# Out:
# array([4.56 , 4.615, 4.67 , 4.725, 4.78 , 4.835, 4.89 , 4.945, 5.   ])

# %%
categorias= ["Categoria1","Categoria2", "Categoria3", "Categoria4", "Categoria5", "Categoria6", "Categoria7", "Categoria8"]

# %%
Micro_Retailer['review_scores_accuracy']=pd.cut(x= Micro_Retailer['review_scores_accuracy'], bins=intervalos, labels=categorias)
Micro_Retailer['review_scores_accuracy']
# Out:
# 0       Categoria8
# 1       Categoria6
# 2       Categoria5
# 3       Categoria3
# 4       Categoria6
#            ...
# 8264    Categoria5
# 8265    Categoria5
# 8266    Categoria5
# 8267    Categoria5
# 8268    Categoria5
# Name: review_scores_accuracy, Length: 8269, dtype: category
# Categories (8, object): ['Categoria1' < 'Categoria2' < 'Categoria3' < 'Categoria4' < 'Categoria5' < 'Categoria6' < 'Categoria7' < 'Categoria8']

# %%
Micro_Retailer['review_scores_accuracy'].value_counts().plot(kind= 'bar', width=0.8, figsize=(10,4), color= "grey")
plt.title('Descripción')
plt.xlabel('Valoración de descripción')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
